# %% [markdown]
# # `Pandas`

# %% [markdown]
# Pandas es una biblioteca de Python ampliamente utilizada para el análisis y manipulación de datos. Proporciona estructuras de datos eficientes y flexibles, así como herramientas para el procesamiento de datos. Con Pandas, puedes importar, limpiar, transformar y analizar datos de manera sencilla y eficiente.

# %% [markdown]
# La estructura de datos principal en Pandas es el `DataFrame`, que es una tabla bidimensional que puede contener datos heterogéneos. Puedes pensar en un *DataFrame* como una hoja de cálculo o una base de datos donde cada columna representa una variable y cada fila representa una observación.

# %% [markdown]
# Pandas ofrece numerosas funcionalidades para realizar tareas comunes de análisis de datos, como la manipulación de columnas y filas, filtrado de datos, agregación, cálculos estadísticos, fusión y concatenación de DataFrames, entre otros.

# %% [markdown]
# ## Características

# %% [markdown]
# Las principales características de esta librería son:
#
# * Define nuevas estructuras de datos basadas en los arrays de la librería NumPy pero con nuevas funcionalidades.
#
# * Permite leer y escribir fácilmente ficheros en formato CSV, Excel y bases de datos SQL.
#
# * Permite acceder a los datos mediante índices o nombres para filas y columnas.
#
# * Ofrece métodos para reordenar, dividir y combinar conjuntos de datos.
#
# * Permite trabajar con series temporales.
#
# * Realiza todas estas operaciones de manera muy eficiente.

# %% [markdown]
# ## Tipos de datos de Pandas

# %% [markdown]
# Pandas dispone de tres estructuras de datos diferentes:
#
# * **Series:** Estructura de una dimensión.
#
# * **DataFrame:** Estructura de dos dimensiones (tablas).
#
# * **Panel:** Estructura de tres dimensiones (cubos).
#
# Estas estructuras se construyen a partir de arrays de la librería NumPy, añadiendo nuevas funcionalidades.

# %% [markdown]
# ## Series

# %% [markdown]
# Son estructuras similares a los arrays de una dimensión. Su tamaño es **inmutable**, es decir, no se puede cambiar, aunque si su contenido.
#
# Dispone de un índice que asocia un nombre a cada elemento del la serie, a través de la cuál se accede al elemento.

# %%
import numpy as np
import pandas as pd

s = pd.Series([1, 2, 5, np.nan , 6, 8], name = 'Mi serie')
print(s)

# %% [markdown]
# **Observación:** `np.nan` se refiere a la representación de un valor `NaN` (`Not a Number`) en la biblioteca NumPy. NaN es un valor especial utilizado para indicar datos faltantes o no válidos en arreglos numéricos.
#
# NaN se utiliza comúnmente en cálculos y operaciones donde puede haber valores faltantes o datos no válidos. En lugar de simplemente dejar un espacio en blanco o usar un valor predeterminado para indicar la ausencia de datos, NaN proporciona una forma estándar de representar estos valores faltantes.

# %% [markdown]
# La clase Series en Pandas acepta varios argumentos adicionales aparte de los datos y el índice. Aquí tienes una lista de algunos argumentos comunes que se pueden utilizar al crear una Serie o al llamar a métodos de una Serie:

# %% [markdown]
# <center>
# <table>
#   <tr>
#     <th>Argumento</th>
#     <th>Descripción</th>
#     <th>Ejemplo de Uso</th>
#   </tr>
#   <tr>
#     <td>name</td>
#     <td>Asigna un nombre a la Serie.</td>
#     <td>pd.Series(data, name="Ventas")</td>
#   </tr>
#   <tr>
#     <td>dtype</td>
#     <td>Especifica el tipo de datos de la Serie.</td>
#     <td>pd.Series(data, dtype=np.float64)</td>
#   </tr>
#   <tr>
#     <td>copy</td>
#     <td>Realiza una copia de los datos.</td>
#     <td>serie.copy()</td>
#   </tr>
#   <!-- <tr>
#     <td>fastpath</td>
#     <td>Habilita el código de camino rápido para la construcción de la Serie.</td>
#     <td>pd.Series(data, fastpath=True)</td>
#   </tr>
#   <tr>
#     <td>verify_integrity</td>
#     <td>Verifica la integridad de los datos al crear la Serie.</td>
#     <td>pd.Series(data, verify_integrity=True)</td>
#   </tr> -->
# </table>
#
# </center>

# %%
# s1 = s.copy()
s1 = s
s1[1]=10
print(s)
print(s1)

# %% [markdown]
# ## Atributos de una serie

# %% [markdown]
# Existen varias propiedades o métodos para ver las características de una serie.
#
# * `s.size` : Devuelve el número de elementos de la serie s.
#
# * `s.index` : Devuelve una lista con los nombres de las filas del DataFrame s.
#
# * `s.dtype` : Devuelve el tipo de datos de los elementos de la serie s.

# %% [markdown]
# ## Creación de una serie a partir de una lista

# %% [markdown]
# `Series(data=lista, index=indices, dtype=tipo)`: Devuelve un objeto de tipo Series con los datos de la lista lista, las filas especificados en la lista indices y el tipo de datos indicado en tipo. Si no se pasa la lista de índices se utilizan como índices los enteros del $0$ al $n-1$ , donde $n$  es el tamaño de la serie. Si no se pasa el tipo de dato se infiere.

# %%
import pandas as pd
s = pd.Series(['Matemáticas', 'Historia', 'Economía', 'Programación', 'Inglés'], dtype='string')
print(s)

# %%
import pandas as pd

lista = [10.1, 20.5, 30.04, 40.011, 50.66]
serie = pd.Series(lista)
# print(serie.index)

print(serie)

# %%
etiquetas = ['A', 'b', 'c', 'd', 'e']
serie = pd.Series(lista, index = etiquetas)
print(serie)

# %% [markdown]
# ## Creación de una serie a partir de un diccionario

# %% [markdown]
# `Series(data=diccionario, index=indices)`: Devuelve un objeto de tipo Series con los valores del diccionario `diccionario` y las filas especificados en la lista `indices`. Si no se pasa la lista de índices se utilizan como índices las claves del diccionario.

# %%
import pandas as pd
# serie = pd.Series({'Matemáticas': 9.0,  'Economía': 4.5, 'Programación': 8.5}, index = ['Matemáticas', 'Economía', 'Ingles', ])
serie = pd.Series({'Matemáticas': 9.0,  'Economía': 4.5, 'Programación': 8.5}, name = "Calificaciones" )
print(serie)

# %%
print(serie.size)
print(serie.index)
print(serie.dtype)

# %% [markdown]
# ## Acceso a los elementos de una serie

# %% [markdown]
# ### Acceso por posición

# %% [markdown]
# Se realiza de forma similar a como se accede a los elementos de un array.
#
# * `s[i]` : Devuelve el elemento que ocupa la posición $i+1$ en la serie s.
# s[lista_posiciones]: Devuelve otra serie con los elementos que ocupan las posiciones de la lista posiciones.

# %% [markdown]
# ### Acceso por índice

# %% [markdown]
# * `s[nombre]` : Devuelve el elemento con el nombre nombre en el índice.
# * s[lista_nombres] : Devuelve otra serie con los elementos correspondientes a los nombres indicadas en la lista nombres en el índice.

# %%
serie[['Matemáticas','Programación']]

# %% [markdown]
# <center>
# <table>
#   <tr>
#     <th>Atributo</th>
#     <th>Descripción</th>
#     <th>Ejemplo de Uso</th>
#   </tr>
#   <tr>
#     <td>values</td>
#     <td>Devuelve los valores de la serie como un array NumPy.</td>
#     <td><code>serie.values</code></td>
#   </tr>
#   <tr>
#     <td>index</td>
#     <td>Devuelve los índices de la serie.</td>
#     <td><code>serie.index</code></td>
#   </tr>
#   <tr>
#     <td>name</td>
#     <td>Devuelve el nombre de la serie.</td>
#     <td><code>serie.name</code></td>
#   </tr>
#   <tr>
#     <td>dtype</td>
#     <td>Devuelve el tipo de datos de la serie.</td>
#     <td><code>serie.dtype</code></td>
#   </tr>
#   <tr>
#     <td>size</td>
#     <td>Devuelve la cantidad de elementos en la serie.</td>
#     <td><code>serie.size</code></td>
#   </tr>
#   <tr>
#     <td>shape</td>
#     <td>Devuelve una tupla que indica la forma de la serie (número de filas, número de columnas).</td>
#     <td><code>serie.shape</code></td>
#   </tr>
#   <tr>
#     <td>ndim</td>
#     <td>Devuelve la cantidad de dimensiones de la serie.</td>
#     <td><code>serie.ndim</code></td>
#   </tr>
#   <tr>
#     <td>empty</td>
#     <td>Devuelve un valor booleano que indica si la serie está vacía o no.</td>
#     <td><code>serie.empty</code></td>
#   </tr>
#   <tr>
#     <td>head()</td>
#     <td>Devuelve las primeras n filas de la serie.</td>
#     <td><code>serie.head(5)</code></td>
#   </tr>
#   <tr>
#     <td>tail()</td>
#     <td>Devuelve las últimas n filas de la serie.</td>
#     <td><code>serie.tail(5)</code></td>
#   </tr>
#   <tr>
#     <td>describe()</td>
#     <td>Calcula estadísticas descriptivas para la serie (conteo, media, desviación estándar, mínimo, percentiles, máximo, entre otros).</td>
#     <td><code>serie.describe()</code></td>
#   </tr>
#   <tr>
#     <td>min()</td>
#     <td>Devuelve el valor mínimo de la serie.</td>
#     <td><code>serie.min()</code></td>
#   </tr>
#   <tr>
#     <td>max()</td>
#     <td>Devuelve el valor máximo de la serie.</td>
#     <td><code>serie.max()</code></td>
#   </tr>
#   <tr>
#     <td>sum()</td>
#     <td>Calcula la suma de los valores en la serie.</td>
#     <td><code>serie.sum()</code></td>
#   </tr>
#   <tr>
#     <td>mean()</td>
#     <td>Calcula la media de los valores en la serie.</td>
#     <td><code>serie.mean()</code></td>
#   </tr>
#   <tr>
#     <td>median()</td>
#     <td>Calcula la mediana de los valores en la serie.</td>
#     <td><code>serie.median()</code></td>
#   </tr>
#   <tr>
#     <td>std()</td>
#     <td>Calcula la desviación estándar de los valores en la serie.</td>
#     <td><code>serie.std()</code></td>
#   </tr>
#   <tr>
#     <td>var()</td>
#     <td>Calcula la varianza de los valores en la serie.</td>
#     <td><code>serie.var()</code></td>
#   </tr>
#   <tr>
#     <td>count()</td>
#     <td>Devuelve la cantidad de valores no nulos en la serie.</td>
#     <td><code>serie.count()</code></td>
#   </tr>
#   <tr>
#     <td>idxmin()</td>
#     <td>Devuelve el índice del valor mínimo en la serie.</td>
#     <td><code>serie.idxmin()</code></td>
#   </tr>
#   <tr>
#     <td>idxmax()</td>
#     <td>Devuelve el índice del valor máximo en la serie.</td>
#     <td><code>serie.idxmax()</code></td>
#   </tr>
#   <tr>
#     <td>all()</td>
#     <td>Devuelve True si todos los elementos de la serie son verdaderos.</td>
#     <td><code>serie.all()</code></td>
#   </tr>
#   <tr>
#     <td>any()</td>
#     <td>Devuelve True si al menos un elemento de la serie es verdadero.</td>
#     <td><code>serie.any()</code></td>
#   </tr>
#   <!-- Agrega más filas según sea necesario -->
# </table>
# </center>

# %%
print(serie.values)

# %%
print(serie.name)

# %%
print(serie.head(2))
# print(serie.tail(2))

# %%
import pandas as pd

precios_viviendas = [250000, 270000, 290000, 320000, 320000, 330000, 340000, 250000]
años = ['2018 Q1', '2018 Q2', '2018 Q3', '2018 Q4', '2019 Q1', '2019 Q2', '2019 Q3', '2019 Q4']

serie_precios = pd.Series(precios_viviendas, index=años)
print(serie_precios)

serie_precios.name = "Precio promedio de viviendas por trimestre"

serie_precios
# Out:
# 2018 Q1    250000
# 2018 Q2    270000
# 2018 Q3    290000
# 2018 Q4    320000
# 2019 Q1    320000
# 2019 Q2    330000
# 2019 Q3    340000
# 2019 Q4    250000
# dtype: int64
# 2018 Q1    250000
# 2018 Q2    270000
# 2018 Q3    290000
# 2018 Q4    320000
# 2019 Q1    320000
# 2019 Q2    330000
# 2019 Q3    340000
# 2019 Q4    250000
# Name: Precio promedio de viviendas por trimestre, dtype: int64

# %%
serie_precios.head(4)
# Out:
# 2018 Q1    250000
# 2018 Q2    270000
# 2018 Q3    290000
# 2018 Q4    320000
# Name: Precio promedio de viviendas por trimestre, dtype: int64

# %%
serie_precios.tail(4)
# Out:
# 2019 Q1    320000
# 2019 Q2    330000
# 2019 Q3    340000
# 2019 Q4    250000
# Name: Precio promedio de viviendas por trimestre, dtype: int64

# %%
print(serie_precios.describe())
# Out:
# count         8.000000
# mean     296250.000000
# std       36228.441865
# min      250000.000000
# 25%      265000.000000
# 50%      305000.000000
# 75%      322500.000000
# max      340000.000000
# Name: Precio promedio de viviendas por trimestre, dtype: float64

# %%
print(serie_precios.value_counts())
# Out:
# Precio promedio de viviendas por trimestre
# 250000    2
# 320000    2
# 270000    1
# 290000    1
# 330000    1
# 340000    1
# Name: count, dtype: int64

# %% [markdown]
# ## Operaciones sobre una `serie`

# %% [markdown]
# Los operadores binarios (`+`, `*`, `/`, etc.) pueden utilizarse con una serie, y devuelven otra serie con el resultado de aplicar la operación a cada elemento de la serie.

# %%
import pandas as pd
serie = pd.Series([1, 2, 3, 4], index = ['Uno', 'Dos', 'Tres', 'Cuatro'])
#serie
serie1 = serie * 2
print(serie1)
print(serie)
# Out:
# Uno       2
# Dos       4
# Tres      6
# Cuatro    8
# dtype: int64
# Uno       1
# Dos       2
# Tres      3
# Cuatro    4
# dtype: int64

# %%
serie = pd.Series([1, 2, 3, 4])
t = serie % 2
t
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# dtype: int64

# %%
serie = pd.Series(['a', 'b', 'c'])
serie * 5

# %% [markdown]
# ## Ordenar una serie

# %% [markdown]
# Para ordenar una serie se utilizan los siguientes métodos:
#
# <center> <code>s.sort_values(ascending=booleano)</code></center>
#
# Devuelve la serie que resulta de ordenar los valores la serie `s`. Si argumento del parámetro ***ascending*** es `True` el orden es creciente y si es `False` decreciente.
#
# <center> <code>df.sort_index(ascending=booleano)</code></center>
#
# Devuelve la serie que resulta de ordenar el índice de la serie `s`. Si el argumento del parámetro ***ascending*** es `True` el orden es creciente y si es `False` decreciente.

# %%
import pandas as pd
s = pd.Series({'Matemáticas': 6.0,  'Economía': 9.5, 'Programación': 8.5})
print(s.sort_values(ascending = False))
# Out:
# Economía        9.5
# Programación    8.5
# Matemáticas     6.0
# dtype: float64

# %% [markdown]
# ## Eliminar los dados desconocidos en una serie

# %% [markdown]
# Los **datos desconocidos** se representan en `Pandas` por `NaN` y los nulos por `None`. Tanto unos como otros suelen ser un problema a la hora de realizar algún análisis de datos, por lo que es habitual eliminarlos. Para eliminarlos de una serie se utiliza el siguiente método:
#
# <center><code>serie.dropna()</code></center>
#
# `serie.dropna()` elimina los datos desconocidos o nulos de la serie `serie`.

# %%
import pandas as pd
import numpy as np
serie = pd.Series(['a', 'b', None, 'c', np.NaN,  'd'])
print(serie)
# Out:
# 0       a
# 1       b
# 2    None
# 3       c
# 4     NaN
# 5       d
# dtype: object

# %%
serie_sin_nan = serie.dropna()

# %%
print(serie_sin_nan)
# Out:
# 0    a
# 1    b
# 3    c
# 5    d
# dtype: object

# %% [markdown]
# ## Función `any`

# %% [markdown]
# La función `any()` en Pandas se utiliza para verificar si al menos un elemento de una serie es verdadero (o no cero en el caso de números). Devuelve `True` **si al menos un elemento** es verdadero y `False` si todos los elementos son falsos.

# %%
import pandas as pd
import numpy as np

serie = pd.Series([1, 2, np.nan, 4, 5])
print(serie)
resultado = serie.isna()
print(resultado)
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# 3    4.0
# 4    5.0
# dtype: float64
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
print(resultado.any())
# Out:
# True

# %%
import pandas as pd
import numpy as np

serie = pd.Series(np.arange(-50,51,10))
print(serie)
# Out:
# 0    -50
# 1    -40
# 2    -30
# 3    -20
# 4    -10
# 5      0
# 6     10
# 7     20
# 8     30
# 9     40
# 10    50
# dtype: int64

# %%
print(serie > 30)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10     True
# dtype: bool

# %%
resultado = (serie > 50).any()
print(resultado)
# Out:
# False

# %%
print(len(serie)- (serie > 30).sum())
# Out:
# 9

# %%
serie = pd.Series(['manzana', 'melon', 'papaya', 'durazno'])
result = serie.str.contains('x').any()
print(result)
# Out:
# False

# %% [markdown]
# ## Aplicar funciones a una serie

# %% [markdown]
# También es posible aplicar una función a cada elemento de la serie mediante el siguiente método:
#
# <center><code>s.apply(f)</code></center>
#
# Devuelve una serie con el resultado de aplicar la función `f` a cada uno de los elementos de la serie `s`.

# %%
import pandas as pd
import numpy as np
from math import log

serie = pd.Series([np.pi, 2*np.pi, 3*np.pi, 4*np.pi])
# serie.apply(np.sin)
s = serie.apply(log)
print(s)
# Out:
# 0    1.144730
# 1    1.837877
# 2    2.243342
# 3    2.531024
# dtype: float64

# %%
serie = pd.Series(['a', 'b', 'c'])
serie.apply(str.upper)
# Out:
# 0    A
# 1    B
# 2    C
# dtype: object

# %%
lista = {'a':}
lista.apply(sum)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-4efed56db7bb> in <cell line: 2>()
#       1 lista = (1,2,3)
# ----> 2 lista.apply(sum)
#
# AttributeError: 'tuple' object has no attribute 'apply'

# %% [markdown]
# ## Filtrar una serie

# %% [markdown]
# Para filtrar una serie y quedarse con los valores que cumplen una determinada condición se utiliza el siguiente método:
#
# <center><code>serie[condicion]</code></center>
#
# Devuelve una serie con los elementos de la serie `serie` que se corresponden con el valor `True` de la lista booleana `condicion`. `condicion` debe ser una lista de valores booleanos de la misma longitud que la serie.

# %%
import pandas as pd
serie = pd.Series({'Matemáticas': 6.0,  'Economía': 4.5, 'Programación': 8.5})
print(serie[serie >= 6])
# Out:
# Matemáticas     6.0
# Programación    8.5
# dtype: float64

# %% [markdown]
# # Dataframe

# %% [markdown]
# Un objeto del tipo `DataFrame` define un conjunto de datos estructurado en forma de tabla donde cada columna es un objeto de tipo `Series`. En general, todos los datos de una misma columna son del mismo tipo, y las filas son registros que pueden contender datos de distintos tipos.

# %% [markdown]
# Un `DataFrame` contiene dos índices, uno para las *filas* y otro para las *columnas*, y se puede acceder a sus elementos mediante los nombres de las filas y las columnas.

# %% [markdown]
# ## Creación de un DataFrame

# %%
import pandas as pd

# %%
dataframe = pd.DataFrame({'A': [1, 2, 3]})
pd.DataFrame({'A': [1, 2, 3]})
print(dataframe)
# Out:
#    A
# 0  1
# 1  2
# 2  3

# %% [markdown]
# ### Creación de un DataFrame a partir de un diccionario de listas

# %% [markdown]
# Para crear un `DataFrame` a partir de un diccionario cuyas claves son los nombres de las columnas y los valores son listas con los datos de las columnas se utiliza el método:
#
# `pd.Dataframe(data=diccionario, index=filas, columns=columnas, dtype=tipos)`
#
# * Devuelve un objeto del tipo DataFrame cuyas columnas son las listas contenidas en los valores del diccionario `diccionario`,
#
# * Los nombres de filas son los indicados en la lista `filas`,
#
# * Los nombres de columnas son los indicados en la lista `columnas` y los tipos indicados en la lista tipos.
#
# * La lista filas tiene que tener el mismo tamaño que las listas del diccionario, mientras que las listas columnas y tipos tienen que tener el mismo tamaño que el diccionario.
#
# * Si no se pasa la lista de filas se utilizan como nombres los enteros empezando en 0. Si no se pasa la lista de columnas se utilizan como nombres las claves del diccionario. Si no se pasa la lista de tipos, se infiere.

# %% [markdown]
# **Observación:** Los valores asociados a las claves del diccionario deben ser listas del mismo tamaño.

# %%
import pandas as pd
datos = {'Nombre':['María', 'Luis', 'Carmen', 'Antonio'],
         'Edad':[18, 22, 20, 21],
         'Carrera':['Economía', 'Medicina', 'Arquitectura', 'Economía'],
         'Correo':['maria@gmail.com', 'luis@yahoo.es', 'carmen@gmail.com', 'antonio@gmail.com']
         }
df = pd.DataFrame(datos)
df
#print(df)
# Out:
#     Nombre  Edad       Carrera             Correo
# 0    María    18      Economía    maria@gmail.com
# 1     Luis    22      Medicina      luis@yahoo.es
# 2   Carmen    20  Arquitectura   carmen@gmail.com
# 3  Antonio    21      Economía  antonio@gmail.com

# %%
# @title Edad

from matplotlib import pyplot as plt
df['Edad'].plot(kind='hist', bins=20, title='Edad')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ### Creación de un DataFrame a partir de una listas de listas

# %% [markdown]
# Para crear un `DataFrame` a **partir de una lista de listas** con los datos de las columnas se utiliza el siguiente método:
#
# `pd.Dataframe(data=listas, index=filas, columns=columnas, dtype=tipos)`
#
# * Devuelve un objeto del tipo `DataFrame` cuyas columnas son los valores de las listas de la lista listas,
#
# * Los nombres de filas indicados en la lista `filas`, los nombres de columnas indicados en la lista `columnas` y los tipos indicados en la lista tipos.
#
# * La lista `filas`, tiene que tener el mismo tamaño que la lista listas mientras que las listas `columnas` y tipos tienen que tener el mismo tamaño que las listas anidadas en `listas`.
#
# * Si no se pasa la lista de `filas` o de `columnas` se utilizan enteros empezando en 0. Si no se pasa la lista de tipos, se infiere.

# %% [markdown]
# **Observación:** Si las listas anidadas en listas no tienen el mismo tamaño, las listas menores se rellenan con valores `NaN`.

# %%
import pandas as pd
df = pd.DataFrame([['María', 18, 'Economia'], ['Luis', 22, 'Actuaria'], ['Carmen', 20]], columns=['Nombre', 'Edad', 'Carrera'])
print(df)

# %% [markdown]
# ### Creación de un DataFrame a partir de una lista de diccionarios

# %% [markdown]
# Para crear un DataFrame a partir de una lista de diccionarios con los datos de las filas, se utiliza el siguiente método:
#
# `pd.Dataframe(data=diccionarios, index=filas, columns=columnas, dtype=tipos)`
#
# * Devuelve un objeto del tipo DataFrame cuyas filas contienen los valores de los diccionarios de la lista diccionarios,
#
# * Los nombres de filas indicados en la lista filas, los nombres de columnas indicados en la lista columnas y los tipos indicados en la lista tipos.
#
# * La lista filas tiene que tener el mismo tamaño que la lista lista. Si no se pasa la lista de filas se utilizan enteros empezando en 0.
#
# * Si no se pasa la lista de columnas se utilizan las claves de los diccionarios.

# %% [markdown]
# **Observación:** Si no se pasa la lista de tipos, se infiere. Si los diccionarios no tienen las mismas claves, las claves que no aparecen en el diccionario se rellenan con valores `NaN`.

# %%
import pandas as pd
df = pd.DataFrame([{'Nombre':'María', 'Edad':18}, {'Edad':22, 'Nombre':'Luis', }, {'Nombre':'Carmen'}])
print(df)

# %% [markdown]
# ### Creación de un DataFrame a partir de un array

# %% [markdown]
# Para crear un DataFrame a partir de un `array` de NumPy se utiliza el siguiente método:
#
# `pd.Dataframe(data=array, index=filas, columns=columnas, dtype=tipo)`
#
# * Devuelde un objeto del tipo `DataFrame` cuyas filas y columnas son las del array `array`,
#
# * Los nombres de filas indicados en la lista `filas`, los nombres de columnas indicados en la lista `columnas` y el tipo indicado en tipo.
#
# * La lista `filas` tiene que tener el mismo tamaño que el número de filas del array y la lista `columnas` el mismo tamaño que el número de columnas del `array`.
#
# <!-- * Si no se pasa la lista de `filas` se utilizan enteros empezando en 0. Si no se pasa la lista de `columnas` se utilizan las claves de los diccionarios. Si no se pasa la lista de tipos, se infiere. -->

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randn(4, 3), columns=['a', 'b', 'c'])
print(df)

# %% [markdown]
# ### Creación de un DataFrame a partir de un fichero CSV o Excel

# %% [markdown]
# Dependiendo del tipo de fichero, existen distintas funciones para importar un DataFrame desde un fichero.
#
# `read_csv(fichero.csv, sep=separador, header=n, index_col=m, na_values=no-validos, decimal=separador-decimal)`
#
# * Devuelve un objeto del tipo DataFrame con los datos del fichero CSV fichero.csv
#
# * Se usan como separador de los datos la cadena separador.
#
# * Como nombres de columnas se utiliza los valores de la fila n y como nombres de filas los valores de la columna m.
#
# *  Si no se indica m se utilizan como nombres de filas los enteros empezando en 0.
#
# * Los valores incluídos en la lista no-validos se convierten en `NaN`.
#
# * Para los datos numéricos se utiliza como separador de decimales el carácter indicado en `separador-decimal`.

# %% [markdown]
# `read_excel(fichero.xlsx, sheet_name=hoja, header=n, index_col=m, na_values=no-validos, decimal=separador-decimal)`
#
# * Devuelve un objeto del tipo `DataFrame` con los datos de la hoja de cálculo hoja del fichero Excel `fichero.xlsx`.
#
# * Como nombres de columnas se utiliza los valores de la fila n y como nombres de filas los valores de la columna m.
#
# * Si no se indica m se utilizan como nombres de filas los enteros empezando en 0. Los valores incluídos en la lista no-validos se convierten en NaN. Para los datos numéricos se utiliza como separador de decimales el carácter indicado en separador-decimal.

# %%
import pandas as pd
df = pd.read_csv('../Archivos/colesterol.csv', sep = ';',decimal='.')

df

# %%
print(df.head())

# %%
df.info()

# %%
df.shape

# %%
df.size

# %%
df.columns

# %%
df.index

# %% [markdown]
# El archivo CSV del Titanic generalmente contiene varias columnas que representan diferentes características de los pasajeros. A continuación se detallan las columnas más comunes y su significado:
#
# El archivo CSV del Titanic generalmente contiene varias columnas que representan diferentes características de los pasajeros. A continuación se detallan las columnas más comunes y su significado:
#
# - **PassengerId**: Un identificador único para cada pasajero.
#
# - **Survived**: Indica si el pasajero sobrevivió (1) o no (0).
#
# - **Pclass**: Clase del pasajero (1 = 1ª clase, 2 = 2ª clase, 3 = 3ª clase).
#
# - **Name**: Nombre del pasajero.
#
# - **Sex**: Género del pasajero (male = hombre, female = mujer).
#
# - **Age**: Edad del pasajero.
#
# - **SibSp**: Número de hermanos/esposos a bordo del Titanic.
#
# - **Parch**: Número de padres/hijos a bordo del Titanic.
#
# - **Ticket**: Número del billete del pasajero.
#
# - **Fare**: Tarifa pagada por el billete.
#
# - **Cabin**: Número de cabina del pasajero.
#
# - **Embarked**: Puerto de embarque del pasajero (C = Cherburgo; Q = Queenstown; S = Southampton).

# %%
import pandas as pd
df  = pd.read_csv('/content/Titanic.csv', sep = ',',decimal='.')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %%
# @title Embarked

from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('Embarked').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Age

from matplotlib import pyplot as plt
df['Age'].plot(kind='hist', bins=20, title='Age')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ## Atributos de un `Dataframe`

# %% [markdown]
# <center>
# <table>
#   <tr>
#     <th>Atributo</th>
#     <th>Descripción</th>
#     <th>Ejemplo de Uso</th>
#   </tr>
#   <tr>
#     <td>shape</td>
#     <td>Devuelve una tupla con el número de filas y columnas del DataFrame</td>
#     <td>df.shape</td>
#   </tr>
#   <tr>
#     <td>columns</td>
#     <td>Devuelve una lista con los nombres de las columnas del DataFrame</td>
#     <td>df.columns</td>
#   </tr>
#   <tr>
#     <td>index</td>
#     <td>Devuelve el índice (etiquetas de fila) del DataFrame</td>
#     <td>df.index</td>
#   </tr>
#   <tr>
#     <td>values</td>
#     <td>Devuelve una matriz NumPy que representa los datos del DataFrame</td>
#     <td>df.values</td>
#   </tr>
#   <tr>
#     <td>dtypes</td>
#     <td>Devuelve los tipos de datos de cada columna del DataFrame</td>
#     <td>df.dtypes</td>
#   </tr>
#   <tr>
#     <td>info()</td>
#     <td>Proporciona información sobre el DataFrame, incluyendo el número total de entradas no nulas por columna y el tipo de datos de cada columna</td>
#     <td>df.info()</td>
#   </tr>
#   <tr>
#     <td>describe()</td>
#     <td>Calcula estadísticas descriptivas para las columnas numéricas del DataFrame</td>
#     <td>df.describe()</td>
#   </tr>
#   <tr>
#     <td>head(n)</td>
#     <td>Devuelve las primeras n filas del DataFrame</td>
#     <td>df.head()</td>
#   </tr>
#   <tr>
#     <td>tail(n)</td>
#     <td>Devuelve las últimas n filas del DataFrame</td>
#     <td>df.tail()</td>
#   </tr>
#   <tr>
#     <td>T</td>
#     <td>Devuelve una transposición del DataFrame, intercambiando filas y columnas</td>
#     <td>df.T</td>
#   </tr>
#   <tr>
#     <td>empty</td>
#     <td>Devuelve un valor booleano que indica si el DataFrame está vacío</td>
#     <td>df.empty</td>
#   </tr>
#   <tr>
#     <td>ndim</td>
#     <td>Devuelve el número de dimensiones del DataFrame</td>
#     <td>df.ndim</td>
#   </tr>
#   <tr>
#     <td>size</td>
#     <td>Devuelve el número total de elementos en el DataFrame</td>
#     <td>df.size</td>
#   </tr>
#   <tr>
#     <td>style</td>
#     <td>Permite aplicar estilos a un DataFrame para resaltar visualmente los datos</td>
#     <td>df.style</td>
#   </tr>
#   <tr>
#     <td>nunique()</td>
#     <td>Devuelve el número de valores únicos en cada columna</td>
#     <td>df['columna'].nunique()</td>
#   </tr>
#   <tr>
#     <td>unique()</td>
#     <td>Devuelve una matriz con los valores únicos en una columna específica</td>
#     <td>df['columna'].unique()</td>
#   </tr>
#   <tr>
#     <td>duplicated()</td>
#     <td>Devuelve una serie booleana que indica si cada fila es duplicada o no</td>
#     <td>df.duplicated()</td>
#   </tr>
#   <tr>
#     <td>drop_duplicates()</td>
#     <td>Elimina las filas duplicadas del DataFrame y devuelve el DataFrame resultante</td>
#     <td>df.drop_duplicates()</td>
#   </tr>
#   <tr>
#     <td>corr()</td>
#     <td>Calcula la correlación entre columnas numéricas en el DataFrame</td>
#     <td>df.corr()</td>
#   </tr>
#   <tr>
#     <td>cov()</td>
#     <td>Calcula la covarianza entre columnas numéricas en el DataFrame</td>
#     <td>df.cov()</td>
#   </tr>
#   <tr>
#     <td>min()</td>
#     <td>Devuelve el valor mínimo de cada columna numérica</td>
#     <td>df.min()</td>
#   </tr>
#   <tr>
#     <td>max()</td>
#     <td>Devuelve el valor máximo de cada columna numérica</td>
#     <td>df.max()</td>
#   </tr>
#   <tr>
#     <td>sum()</td>
#     <td>Calcula la suma de los valores en cada columna numérica</td>
#     <td>df.sum()</td>
#   </tr>
#   <tr>
#     <td>mean()</td>
#     <td>Calcula la media de los valores en cada columna numérica</td>
#     <td>df.mean()</td>
#   </tr>
#   <tr>
#     <td>median()</td>
#     <td>Calcula la mediana de los valores en cada columna numérica</td>
#     <td>df.median()</td>
#   </tr>
#   <tr>
#     <td>std()</td>
#     <td>Calcula la desviación estándar de los valores en cada columna numérica</td>
#     <td>df.std()</td>
#   </tr>
#   <tr>
#     <td>var()</td>
#     <td>Calcula la varianza de los valores en cada columna numérica</td>
#     <td>df.var()</td>
#   </tr>
#   <tr>
#     <td>count()</td>
#     <td>Calcula el número de valores no nulos en cada columna</td>
#     <td>df.count()</td>
#   </tr>
#   <tr>
#     <td>isnull()</td>
#     <td>Devuelve una matriz booleana que indica qué valores son nulos</td>
#     <td>df.isnull()</td>
#   </tr>
#   <tr>
#     <td>notnull()</td>
#     <td>Devuelve una matriz booleana que indica qué valores no son nulos</td>
#     <td>df.notnull()</td>
#   </tr>
#   <tr>
#     <td>astype()</td>
#     <td>Convierte el tipo de datos de una o varias columnas en un tipo de datos específico</td>
#     <td>df['columna'].astype('tipo')</td>
#   </tr>
#   <tr>
#     <td>fillna()</td>
#     <td>Rellena los valores faltantes (NaN) en el DataFrame con un valor específico</td>
#     <td>df.fillna(valor)</td>
#   </tr>
#   <tr>
#     <td>dropna()</td>
#     <td>Elimina las filas con valores faltantes (NaN) del DataFrame y devuelve el DataFrame resultante</td>
#     <td>df.dropna()</td>
#   </tr>
# </table>
#
# </center>

# %%
import pandas as pd
df = pd.read_csv('../Archivos/colesterol.csv', sep = ';',decimal='.')
df

styled_df = df.style.highlight_max(color='lightgreen', axis=0, subset={})
styled_df
# Out:
# <style type="text/css">
# #T_394b5_row1_col2, #T_394b5_row3_col2, #T_394b5_row4_col2, #T_394b5_row5_col1, #T_394b5_row7_col2, #T_394b5_row9_col0, #T_394b5_row9_col5, #T_394b5_row10_col2, #T_394b5_row12_col3, #T_394b5_row12_col4, #T_394b5_row13_col2 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_394b5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_394b5_level0_col0" class="col_heading level0 col0" >nombre</th>
#       <th id="T_394b5_level0_col1" class="col_heading level0 col1" >edad</th>
#       <th id="T_394b5_level0_col2" class="col_heading level0 col2" >sexo</th>
#       <th id="T_394b5_level0_col3" class="col_heading level0 col3" >peso</th>
#       <th id="T_394b5_level0_col4" class="col_heading level0 col4" >altura</th>
#       <th id="T_394b5_level0_col5" class="col_heading level0 col5" >colesterol</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_394b5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_394b5_row0_col0" class="data row0 col0" >José Luis Martínez Izquierdo</td>
#       <td id="T_394b5_row0_col1" class="data row0 col1" >18</td>
#       <td id="T_394b5_row0_col2" class="data row0 col2" >H</td>
#       <td id="T_394b5_row0_col3" class="data row0 col3" >85.000000</td>
#       <td id="T_394b5_row0_col4" class="data row0 col4" >1,79</td>
#       <td id="T_394b5_row0_col5" class="data row0 col5" >182.000000</td>
#     </tr>
#     <tr>
#       <th id="T_394b5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_394b5_row1_col0" class="data row1 col0" >Rosa Díaz Díaz</td>
#       <td id="T_394b5_row1_col1" class="data row1 col1" >32</td>
#       <td id="T_394b5_row1_col2" class="data row1 col2" >M</td>
#       <td id="T_394b5_row1_col3" class="data row1 col3" >65.000000</td>
#       <td id="T_394b5_row1_col4" class="data row1 col4" >1,73</td>
#       <td id="T_394b5_row1_col5" class="data row1 col5" >232.000000</td>
#     </tr>
#     <tr>
#       <th id="T_394b5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_394b5_row2_col0" class="data row2 col0" >Javier García Sánchez</td>
#       <td id="T_394b5_row2_col1" class="data row2 col1" >24</td>
#       <td id="T_394b5_row2_col2" class="data row2 col2" >H</td>
#       <td id="T_394b5_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_394b5_row2_col4" class="data row2 col4" >1,81</td>
#       <td id="T_394b5_row2_col5" class="data row2 col5" >191.000000</td>
#     </tr>
#     <tr>
#       <th id="T_394b5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_394b5_row3_col0" class="data row3 col0" >Carmen López Pinzón</td>
#       <td id="T_394b5_row3_col1" class="data row3 col1" >35</td>
#       <td id="T_394b5_row3_col2" class="data row3 col2" >M</td>
#       <td id="T_394b5_row3_col3" class="data row3 col3" >65.000000</td>
#       <td id="T_394b5_row3_col4" class="data row3 col4" >1,70</td>
#       <td id="T_394b5_row3_col5" class="data row3 col5" >200.000000</td>
#     </tr>
#     <tr>
#       <th id="T_394b5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_394b5_row4_col0" class="data row4 col0" >Marisa López Collado</td>
#       <td id="T_394b5_row4_col1" class="data row4 col1" >46</td>
#       <td id="T_394b5_row4_col2" class="data row4 col2" >M</td>
#       <td id="T_394b5_row4_col3" class="data row4 col3" >51.000000</td>
#       <td id="T_394b5_row4_col4" class="data row4 col4" >1,58</td>
#       <td id="T_394b5_row4_col5" class="data row4 col5" >148.000000</td>
#     </tr>
#     <tr>
#       <th id="T_394b5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_394b5_row5_col0" class="data row5 col0" >Antonio Ruiz Cruz</td>
#       <td id="T_394b5_row5_col1" class="data row5 col1" >68</td>
#       <td id="T_394b5_row5_col2" class="data row5 col2" >H</td>
#       <td id="T_394b5_row5_col3" class="data row5 col3" >66.000000</td>
#       <td id="T_394b5_row5_col4" class="data row5 col4" >1,74</td>
#       <td id="T_394b5_row5_col5" class="data row5 col5" >249.000000</td>
#     </tr>
#     <tr>
#       <th id="T_394b5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_394b5_row6_col0" class="data row6 col0" >Antonio Fernández Ocaña</td>
#       <td id="T_394b5_row6_col1" class="data row6 col1" >51</td>
#       <td id="T_394b5_row6_col2" class="data row6 col2" >H</td>
#       <td id="T_394b5_row6_col3" class="data row6 col3" >62.000000</td>
#       <td id="T_394b5_row6_col4" class="data row6 col4" >1,72</td>
#       <td id="T_394b5_row6_col5" class="data row6 col5" >276.000000</td>
#     </tr>
#     <tr>
#       <th id="T_394b5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_394b5_row7_col0" class="data row7 col0" >Pilar Martín González</td>
#       <td id="T_394b5_row7_col1" class="data row7 col1" >22</td>
#       <td id="T_394b5_row7_col2" class="data row7 col2" >M</td>
#       <td id="T_394b5_row7_col3" class="data row7 col3" >60.000000</td>
#       <td id="T_394b5_row7_col4" class="data row7 col4" >1,66</td>
#       <td id="T_394b5_row7_col5" class="data row7 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_394b5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_394b5_row8_col0" class="data row8 col0" >Pedro Gálvez Tenorio</td>
#       <td id="T_394b5_row8_col1" class="data row8 col1" >35</td>
#       <td id="T_394b5_row8_col2" class="data row8 col2" >H</td>
#       <td id="T_394b5_row8_col3" class="data row8 col3" >90.000000</td>
#       <td id="T_394b5_row8_col4" class="data row8 col4" >1,94</td>
#       <td id="T_394b5_row8_col5" class="data row8 col5" >241.000000</td>
#     </tr>
#     <tr>
#       <th id="T_394b5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_394b5_row9_col0" class="data row9 col0" >Santiago Reillo Manzano</td>
#       <td id="T_394b5_row9_col1" class="data row9 col1" >46</td>
#       <td id="T_394b5_row9_col2" class="data row9 col2" >H</td>
#       <td id="T_394b5_row9_col3" class="data row9 col3" >75.000000</td>
#       <td id="T_394b5_row9_col4" class="data row9 col4" >1,85</td>
#       <td id="T_394b5_row9_col5" class="data row9 col5" >280.000000</td>
#     </tr>
#     <tr>
#       <th id="T_394b5_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_394b5_row10_col0" class="data row10 col0" >Macarena Álvarez Luna</td>
#       <td id="T_394b5_row10_col1" class="data row10 col1" >53</td>
#       <td id="T_394b5_row10_col2" class="data row10 col2" >M</td>
#       <td id="T_394b5_row10_col3" class="data row10 col3" >55.000000</td>
#       <td id="T_394b5_row10_col4" class="data row10 col4" >1,62</td>
#       <td id="T_394b5_row10_col5" class="data row10 col5" >262.000000</td>
#     </tr>
#     <tr>
#       <th id="T_394b5_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_394b5_row11_col0" class="data row11 col0" >José María de la Guía Sanz</td>
#       <td id="T_394b5_row11_col1" class="data row11 col1" >58</td>
#       <td id="T_394b5_row11_col2" class="data row11 col2" >H</td>
#       <td id="T_394b5_row11_col3" class="data row11 col3" >78.000000</td>
#       <td id="T_394b5_row11_col4" class="data row11 col4" >1,87</td>
#       <td id="T_394b5_row11_col5" class="data row11 col5" >198.000000</td>
#     </tr>
#     <tr>
#       <th id="T_394b5_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_394b5_row12_col0" class="data row12 col0" >Miguel Angel Cuadrado Gutiérrez</td>
#       <td id="T_394b5_row12_col1" class="data row12 col1" >27</td>
#       <td id="T_394b5_row12_col2" class="data row12 col2" >H</td>
#       <td id="T_394b5_row12_col3" class="data row12 col3" >109.000000</td>
#       <td id="T_394b5_row12_col4" class="data row12 col4" >1,98</td>
#       <td id="T_394b5_row12_col5" class="data row12 col5" >210.000000</td>
#     </tr>
#     <tr>
#       <th id="T_394b5_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_394b5_row13_col0" class="data row13 col0" >Carolina Rubio Moreno</td>
#       <td id="T_394b5_row13_col1" class="data row13 col1" >20</td>
#       <td id="T_394b5_row13_col2" class="data row13 col2" >M</td>
#       <td id="T_39

# %%
styled_df = df.style.highlight_min(color='lightcoral', axis=0)
styled_df
# Out:
# <style type="text/css">
# #T_58573_row0_col1, #T_58573_row0_col2, #T_58573_row2_col2, #T_58573_row4_col3, #T_58573_row4_col4, #T_58573_row4_col5, #T_58573_row5_col2, #T_58573_row6_col0, #T_58573_row6_col2, #T_58573_row8_col2, #T_58573_row9_col2, #T_58573_row11_col2, #T_58573_row12_col2 {
#   background-color: lightcoral;
# }
# </style>
# <table id="T_58573">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_58573_level0_col0" class="col_heading level0 col0" >nombre</th>
#       <th id="T_58573_level0_col1" class="col_heading level0 col1" >edad</th>
#       <th id="T_58573_level0_col2" class="col_heading level0 col2" >sexo</th>
#       <th id="T_58573_level0_col3" class="col_heading level0 col3" >peso</th>
#       <th id="T_58573_level0_col4" class="col_heading level0 col4" >altura</th>
#       <th id="T_58573_level0_col5" class="col_heading level0 col5" >colesterol</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_58573_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_58573_row0_col0" class="data row0 col0" >José Luis Martínez Izquierdo</td>
#       <td id="T_58573_row0_col1" class="data row0 col1" >18</td>
#       <td id="T_58573_row0_col2" class="data row0 col2" >H</td>
#       <td id="T_58573_row0_col3" class="data row0 col3" >85.000000</td>
#       <td id="T_58573_row0_col4" class="data row0 col4" >1,79</td>
#       <td id="T_58573_row0_col5" class="data row0 col5" >182.000000</td>
#     </tr>
#     <tr>
#       <th id="T_58573_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_58573_row1_col0" class="data row1 col0" >Rosa Díaz Díaz</td>
#       <td id="T_58573_row1_col1" class="data row1 col1" >32</td>
#       <td id="T_58573_row1_col2" class="data row1 col2" >M</td>
#       <td id="T_58573_row1_col3" class="data row1 col3" >65.000000</td>
#       <td id="T_58573_row1_col4" class="data row1 col4" >1,73</td>
#       <td id="T_58573_row1_col5" class="data row1 col5" >232.000000</td>
#     </tr>
#     <tr>
#       <th id="T_58573_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_58573_row2_col0" class="data row2 col0" >Javier García Sánchez</td>
#       <td id="T_58573_row2_col1" class="data row2 col1" >24</td>
#       <td id="T_58573_row2_col2" class="data row2 col2" >H</td>
#       <td id="T_58573_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_58573_row2_col4" class="data row2 col4" >1,81</td>
#       <td id="T_58573_row2_col5" class="data row2 col5" >191.000000</td>
#     </tr>
#     <tr>
#       <th id="T_58573_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_58573_row3_col0" class="data row3 col0" >Carmen López Pinzón</td>
#       <td id="T_58573_row3_col1" class="data row3 col1" >35</td>
#       <td id="T_58573_row3_col2" class="data row3 col2" >M</td>
#       <td id="T_58573_row3_col3" class="data row3 col3" >65.000000</td>
#       <td id="T_58573_row3_col4" class="data row3 col4" >1,70</td>
#       <td id="T_58573_row3_col5" class="data row3 col5" >200.000000</td>
#     </tr>
#     <tr>
#       <th id="T_58573_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_58573_row4_col0" class="data row4 col0" >Marisa López Collado</td>
#       <td id="T_58573_row4_col1" class="data row4 col1" >46</td>
#       <td id="T_58573_row4_col2" class="data row4 col2" >M</td>
#       <td id="T_58573_row4_col3" class="data row4 col3" >51.000000</td>
#       <td id="T_58573_row4_col4" class="data row4 col4" >1,58</td>
#       <td id="T_58573_row4_col5" class="data row4 col5" >148.000000</td>
#     </tr>
#     <tr>
#       <th id="T_58573_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_58573_row5_col0" class="data row5 col0" >Antonio Ruiz Cruz</td>
#       <td id="T_58573_row5_col1" class="data row5 col1" >68</td>
#       <td id="T_58573_row5_col2" class="data row5 col2" >H</td>
#       <td id="T_58573_row5_col3" class="data row5 col3" >66.000000</td>
#       <td id="T_58573_row5_col4" class="data row5 col4" >1,74</td>
#       <td id="T_58573_row5_col5" class="data row5 col5" >249.000000</td>
#     </tr>
#     <tr>
#       <th id="T_58573_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_58573_row6_col0" class="data row6 col0" >Antonio Fernández Ocaña</td>
#       <td id="T_58573_row6_col1" class="data row6 col1" >51</td>
#       <td id="T_58573_row6_col2" class="data row6 col2" >H</td>
#       <td id="T_58573_row6_col3" class="data row6 col3" >62.000000</td>
#       <td id="T_58573_row6_col4" class="data row6 col4" >1,72</td>
#       <td id="T_58573_row6_col5" class="data row6 col5" >276.000000</td>
#     </tr>
#     <tr>
#       <th id="T_58573_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_58573_row7_col0" class="data row7 col0" >Pilar Martín González</td>
#       <td id="T_58573_row7_col1" class="data row7 col1" >22</td>
#       <td id="T_58573_row7_col2" class="data row7 col2" >M</td>
#       <td id="T_58573_row7_col3" class="data row7 col3" >60.000000</td>
#       <td id="T_58573_row7_col4" class="data row7 col4" >1,66</td>
#       <td id="T_58573_row7_col5" class="data row7 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_58573_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_58573_row8_col0" class="data row8 col0" >Pedro Gálvez Tenorio</td>
#       <td id="T_58573_row8_col1" class="data row8 col1" >35</td>
#       <td id="T_58573_row8_col2" class="data row8 col2" >H</td>
#       <td id="T_58573_row8_col3" class="data row8 col3" >90.000000</td>
#       <td id="T_58573_row8_col4" class="data row8 col4" >1,94</td>
#       <td id="T_58573_row8_col5" class="data row8 col5" >241.000000</td>
#     </tr>
#     <tr>
#       <th id="T_58573_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_58573_row9_col0" class="data row9 col0" >Santiago Reillo Manzano</td>
#       <td id="T_58573_row9_col1" class="data row9 col1" >46</td>
#       <td id="T_58573_row9_col2" class="data row9 col2" >H</td>
#       <td id="T_58573_row9_col3" class="data row9 col3" >75.000000</td>
#       <td id="T_58573_row9_col4" class="data row9 col4" >1,85</td>
#       <td id="T_58573_row9_col5" class="data row9 col5" >280.000000</td>
#     </tr>
#     <tr>
#       <th id="T_58573_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_58573_row10_col0" class="data row10 col0" >Macarena Álvarez Luna</td>
#       <td id="T_58573_row10_col1" class="data row10 col1" >53</td>
#       <td id="T_58573_row10_col2" class="data row10 col2" >M</td>
#       <td id="T_58573_row10_col3" class="data row10 col3" >55.000000</td>
#       <td id="T_58573_row10_col4" class="data row10 col4" >1,62</td>
#       <td id="T_58573_row10_col5" class="data row10 col5" >262.000000</td>
#     </tr>
#     <tr>
#       <th id="T_58573_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_58573_row11_col0" class="data row11 col0" >José María de la Guía Sanz</td>
#       <td id="T_58573_row11_col1" class="data row11 col1" >58</td>
#       <td id="T_58573_row11_col2" class="data row11 col2" >H</td>
#       <td id="T_58573_row11_col3" class="data row11 col3" >78.000000</td>
#       <td id="T_58573_row11_col4" class="data row11 col4" >1,87</td>
#       <td id="T_58573_row11_col5" class="data row11 col5" >198.000000</td>
#     </tr>
#     <tr>
#       <th id="T_58573_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_58573_row12_col0" class="data row12 col0" >Miguel Angel Cuadrado Gutiérrez</td>
#       <td id="T_58573_row12_col1" class="data row12 col1" >27</td>
#       <td id="T_58573_row12_col2" class="data row12 col2" >H</td>
#       <td id="T_58573_row12_col3" class="data row12 col3" >109.000000</td>
#       <td id="T_58573_row12_col4" class="data row12 col4" >1,98</td>
#       <td id="T_58573_row12_col5" class="data row12 col5" >210.000000</td>
#     </tr>
#     <tr>
#       <th id="T_58573_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_58573_row13_col0" class="data row13 col0" >Carolina Rubio Moreno</td>
#       <td id="T_58573_row13_col1" class="data row13 col1" >20</td>
#       <td id="T_58573_row13_col2" class="data

# %%
styled_df = df.style.format({'colesterol': '{:.2f}'})
styled_df
# Out:
# <style type="text/css">
# </style>
# <table id="T_2c086">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2c086_level0_col0" class="col_heading level0 col0" >nombre</th>
#       <th id="T_2c086_level0_col1" class="col_heading level0 col1" >edad</th>
#       <th id="T_2c086_level0_col2" class="col_heading level0 col2" >sexo</th>
#       <th id="T_2c086_level0_col3" class="col_heading level0 col3" >peso</th>
#       <th id="T_2c086_level0_col4" class="col_heading level0 col4" >altura</th>
#       <th id="T_2c086_level0_col5" class="col_heading level0 col5" >colesterol</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c086_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2c086_row0_col0" class="data row0 col0" >José Luis Martínez Izquierdo</td>
#       <td id="T_2c086_row0_col1" class="data row0 col1" >18</td>
#       <td id="T_2c086_row0_col2" class="data row0 col2" >H</td>
#       <td id="T_2c086_row0_col3" class="data row0 col3" >85.000000</td>
#       <td id="T_2c086_row0_col4" class="data row0 col4" >1,79</td>
#       <td id="T_2c086_row0_col5" class="data row0 col5" >182.00</td>
#     </tr>
#     <tr>
#       <th id="T_2c086_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2c086_row1_col0" class="data row1 col0" >Rosa Díaz Díaz</td>
#       <td id="T_2c086_row1_col1" class="data row1 col1" >32</td>
#       <td id="T_2c086_row1_col2" class="data row1 col2" >M</td>
#       <td id="T_2c086_row1_col3" class="data row1 col3" >65.000000</td>
#       <td id="T_2c086_row1_col4" class="data row1 col4" >1,73</td>
#       <td id="T_2c086_row1_col5" class="data row1 col5" >232.00</td>
#     </tr>
#     <tr>
#       <th id="T_2c086_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2c086_row2_col0" class="data row2 col0" >Javier García Sánchez</td>
#       <td id="T_2c086_row2_col1" class="data row2 col1" >24</td>
#       <td id="T_2c086_row2_col2" class="data row2 col2" >H</td>
#       <td id="T_2c086_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_2c086_row2_col4" class="data row2 col4" >1,81</td>
#       <td id="T_2c086_row2_col5" class="data row2 col5" >191.00</td>
#     </tr>
#     <tr>
#       <th id="T_2c086_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2c086_row3_col0" class="data row3 col0" >Carmen López Pinzón</td>
#       <td id="T_2c086_row3_col1" class="data row3 col1" >35</td>
#       <td id="T_2c086_row3_col2" class="data row3 col2" >M</td>
#       <td id="T_2c086_row3_col3" class="data row3 col3" >65.000000</td>
#       <td id="T_2c086_row3_col4" class="data row3 col4" >1,70</td>
#       <td id="T_2c086_row3_col5" class="data row3 col5" >200.00</td>
#     </tr>
#     <tr>
#       <th id="T_2c086_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2c086_row4_col0" class="data row4 col0" >Marisa López Collado</td>
#       <td id="T_2c086_row4_col1" class="data row4 col1" >46</td>
#       <td id="T_2c086_row4_col2" class="data row4 col2" >M</td>
#       <td id="T_2c086_row4_col3" class="data row4 col3" >51.000000</td>
#       <td id="T_2c086_row4_col4" class="data row4 col4" >1,58</td>
#       <td id="T_2c086_row4_col5" class="data row4 col5" >148.00</td>
#     </tr>
#     <tr>
#       <th id="T_2c086_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2c086_row5_col0" class="data row5 col0" >Antonio Ruiz Cruz</td>
#       <td id="T_2c086_row5_col1" class="data row5 col1" >68</td>
#       <td id="T_2c086_row5_col2" class="data row5 col2" >H</td>
#       <td id="T_2c086_row5_col3" class="data row5 col3" >66.000000</td>
#       <td id="T_2c086_row5_col4" class="data row5 col4" >1,74</td>
#       <td id="T_2c086_row5_col5" class="data row5 col5" >249.00</td>
#     </tr>
#     <tr>
#       <th id="T_2c086_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2c086_row6_col0" class="data row6 col0" >Antonio Fernández Ocaña</td>
#       <td id="T_2c086_row6_col1" class="data row6 col1" >51</td>
#       <td id="T_2c086_row6_col2" class="data row6 col2" >H</td>
#       <td id="T_2c086_row6_col3" class="data row6 col3" >62.000000</td>
#       <td id="T_2c086_row6_col4" class="data row6 col4" >1,72</td>
#       <td id="T_2c086_row6_col5" class="data row6 col5" >276.00</td>
#     </tr>
#     <tr>
#       <th id="T_2c086_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2c086_row7_col0" class="data row7 col0" >Pilar Martín González</td>
#       <td id="T_2c086_row7_col1" class="data row7 col1" >22</td>
#       <td id="T_2c086_row7_col2" class="data row7 col2" >M</td>
#       <td id="T_2c086_row7_col3" class="data row7 col3" >60.000000</td>
#       <td id="T_2c086_row7_col4" class="data row7 col4" >1,66</td>
#       <td id="T_2c086_row7_col5" class="data row7 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2c086_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2c086_row8_col0" class="data row8 col0" >Pedro Gálvez Tenorio</td>
#       <td id="T_2c086_row8_col1" class="data row8 col1" >35</td>
#       <td id="T_2c086_row8_col2" class="data row8 col2" >H</td>
#       <td id="T_2c086_row8_col3" class="data row8 col3" >90.000000</td>
#       <td id="T_2c086_row8_col4" class="data row8 col4" >1,94</td>
#       <td id="T_2c086_row8_col5" class="data row8 col5" >241.00</td>
#     </tr>
#     <tr>
#       <th id="T_2c086_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2c086_row9_col0" class="data row9 col0" >Santiago Reillo Manzano</td>
#       <td id="T_2c086_row9_col1" class="data row9 col1" >46</td>
#       <td id="T_2c086_row9_col2" class="data row9 col2" >H</td>
#       <td id="T_2c086_row9_col3" class="data row9 col3" >75.000000</td>
#       <td id="T_2c086_row9_col4" class="data row9 col4" >1,85</td>
#       <td id="T_2c086_row9_col5" class="data row9 col5" >280.00</td>
#     </tr>
#     <tr>
#       <th id="T_2c086_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2c086_row10_col0" class="data row10 col0" >Macarena Álvarez Luna</td>
#       <td id="T_2c086_row10_col1" class="data row10 col1" >53</td>
#       <td id="T_2c086_row10_col2" class="data row10 col2" >M</td>
#       <td id="T_2c086_row10_col3" class="data row10 col3" >55.000000</td>
#       <td id="T_2c086_row10_col4" class="data row10 col4" >1,62</td>
#       <td id="T_2c086_row10_col5" class="data row10 col5" >262.00</td>
#     </tr>
#     <tr>
#       <th id="T_2c086_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2c086_row11_col0" class="data row11 col0" >José María de la Guía Sanz</td>
#       <td id="T_2c086_row11_col1" class="data row11 col1" >58</td>
#       <td id="T_2c086_row11_col2" class="data row11 col2" >H</td>
#       <td id="T_2c086_row11_col3" class="data row11 col3" >78.000000</td>
#       <td id="T_2c086_row11_col4" class="data row11 col4" >1,87</td>
#       <td id="T_2c086_row11_col5" class="data row11 col5" >198.00</td>
#     </tr>
#     <tr>
#       <th id="T_2c086_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2c086_row12_col0" class="data row12 col0" >Miguel Angel Cuadrado Gutiérrez</td>
#       <td id="T_2c086_row12_col1" class="data row12 col1" >27</td>
#       <td id="T_2c086_row12_col2" class="data row12 col2" >H</td>
#       <td id="T_2c086_row12_col3" class="data row12 col3" >109.000000</td>
#       <td id="T_2c086_row12_col4" class="data row12 col4" >1,98</td>
#       <td id="T_2c086_row12_col5" class="data row12 col5" >210.00</td>
#     </tr>
#     <tr>
#       <th id="T_2c086_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2c086_row13_col0" class="data row13 col0" >Carolina Rubio Moreno</td>
#       <td id="T_2c086_row13_col1" class="data row13 col1" >20</td>
#       <td id="T_2c086_row13_col2" class="data row13 col2" >M</td>
#       <td id="T_2c086_row13_col3" class="data row13 col3" >61.000000</td>
#       <td id="T_2c086_row13_col4" class="data row13 col4" >1,77</td>
#       <td id="T_2c086_row13_col5" class="data row13 col5" >194.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
styled_df = df.style.background_gradient(subset=['colesterol'], cmap='viridis')
styled_df
# Out:
# <style type="text/css">
# #T_71c76_row0_col5 {
#   background-color: #3a538b;
#   color: #f1f1f1;
# }
# #T_71c76_row1_col5 {
#   background-color: #2ab07f;
#   color: #f1f1f1;
# }
# #T_71c76_row2_col5 {
#   background-color: #31668e;
#   color: #f1f1f1;
# }
# #T_71c76_row3_col5 {
#   background-color: #2a768e;
#   color: #f1f1f1;
# }
# #T_71c76_row4_col5 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_71c76_row5_col5 {
#   background-color: #65cb5e;
#   color: #000000;
# }
# #T_71c76_row6_col5 {
#   background-color: #ece51b;
#   color: #000000;
# }
# #T_71c76_row7_col5 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_71c76_row8_col5 {
#   background-color: #46c06f;
#   color: #f1f1f1;
# }
# #T_71c76_row9_col5 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_71c76_row10_col5 {
#   background-color: #a5db36;
#   color: #000000;
# }
# #T_71c76_row11_col5 {
#   background-color: #2c728e;
#   color: #f1f1f1;
# }
# #T_71c76_row12_col5 {
#   background-color: #23898e;
#   color: #f1f1f1;
# }
# #T_71c76_row13_col5 {
#   background-color: #2f6c8e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_71c76">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_71c76_level0_col0" class="col_heading level0 col0" >nombre</th>
#       <th id="T_71c76_level0_col1" class="col_heading level0 col1" >edad</th>
#       <th id="T_71c76_level0_col2" class="col_heading level0 col2" >sexo</th>
#       <th id="T_71c76_level0_col3" class="col_heading level0 col3" >peso</th>
#       <th id="T_71c76_level0_col4" class="col_heading level0 col4" >altura</th>
#       <th id="T_71c76_level0_col5" class="col_heading level0 col5" >colesterol</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71c76_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_71c76_row0_col0" class="data row0 col0" >José Luis Martínez Izquierdo</td>
#       <td id="T_71c76_row0_col1" class="data row0 col1" >18</td>
#       <td id="T_71c76_row0_col2" class="data row0 col2" >H</td>
#       <td id="T_71c76_row0_col3" class="data row0 col3" >85.000000</td>
#       <td id="T_71c76_row0_col4" class="data row0 col4" >1,79</td>
#       <td id="T_71c76_row0_col5" class="data row0 col5" >182.000000</td>
#     </tr>
#     <tr>
#       <th id="T_71c76_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_71c76_row1_col0" class="data row1 col0" >Rosa Díaz Díaz</td>
#       <td id="T_71c76_row1_col1" class="data row1 col1" >32</td>
#       <td id="T_71c76_row1_col2" class="data row1 col2" >M</td>
#       <td id="T_71c76_row1_col3" class="data row1 col3" >65.000000</td>
#       <td id="T_71c76_row1_col4" class="data row1 col4" >1,73</td>
#       <td id="T_71c76_row1_col5" class="data row1 col5" >232.000000</td>
#     </tr>
#     <tr>
#       <th id="T_71c76_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_71c76_row2_col0" class="data row2 col0" >Javier García Sánchez</td>
#       <td id="T_71c76_row2_col1" class="data row2 col1" >24</td>
#       <td id="T_71c76_row2_col2" class="data row2 col2" >H</td>
#       <td id="T_71c76_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_71c76_row2_col4" class="data row2 col4" >1,81</td>
#       <td id="T_71c76_row2_col5" class="data row2 col5" >191.000000</td>
#     </tr>
#     <tr>
#       <th id="T_71c76_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_71c76_row3_col0" class="data row3 col0" >Carmen López Pinzón</td>
#       <td id="T_71c76_row3_col1" class="data row3 col1" >35</td>
#       <td id="T_71c76_row3_col2" class="data row3 col2" >M</td>
#       <td id="T_71c76_row3_col3" class="data row3 col3" >65.000000</td>
#       <td id="T_71c76_row3_col4" class="data row3 col4" >1,70</td>
#       <td id="T_71c76_row3_col5" class="data row3 col5" >200.000000</td>
#     </tr>
#     <tr>
#       <th id="T_71c76_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_71c76_row4_col0" class="data row4 col0" >Marisa López Collado</td>
#       <td id="T_71c76_row4_col1" class="data row4 col1" >46</td>
#       <td id="T_71c76_row4_col2" class="data row4 col2" >M</td>
#       <td id="T_71c76_row4_col3" class="data row4 col3" >51.000000</td>
#       <td id="T_71c76_row4_col4" class="data row4 col4" >1,58</td>
#       <td id="T_71c76_row4_col5" class="data row4 col5" >148.000000</td>
#     </tr>
#     <tr>
#       <th id="T_71c76_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_71c76_row5_col0" class="data row5 col0" >Antonio Ruiz Cruz</td>
#       <td id="T_71c76_row5_col1" class="data row5 col1" >68</td>
#       <td id="T_71c76_row5_col2" class="data row5 col2" >H</td>
#       <td id="T_71c76_row5_col3" class="data row5 col3" >66.000000</td>
#       <td id="T_71c76_row5_col4" class="data row5 col4" >1,74</td>
#       <td id="T_71c76_row5_col5" class="data row5 col5" >249.000000</td>
#     </tr>
#     <tr>
#       <th id="T_71c76_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_71c76_row6_col0" class="data row6 col0" >Antonio Fernández Ocaña</td>
#       <td id="T_71c76_row6_col1" class="data row6 col1" >51</td>
#       <td id="T_71c76_row6_col2" class="data row6 col2" >H</td>
#       <td id="T_71c76_row6_col3" class="data row6 col3" >62.000000</td>
#       <td id="T_71c76_row6_col4" class="data row6 col4" >1,72</td>
#       <td id="T_71c76_row6_col5" class="data row6 col5" >276.000000</td>
#     </tr>
#     <tr>
#       <th id="T_71c76_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_71c76_row7_col0" class="data row7 col0" >Pilar Martín González</td>
#       <td id="T_71c76_row7_col1" class="data row7 col1" >22</td>
#       <td id="T_71c76_row7_col2" class="data row7 col2" >M</td>
#       <td id="T_71c76_row7_col3" class="data row7 col3" >60.000000</td>
#       <td id="T_71c76_row7_col4" class="data row7 col4" >1,66</td>
#       <td id="T_71c76_row7_col5" class="data row7 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_71c76_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_71c76_row8_col0" class="data row8 col0" >Pedro Gálvez Tenorio</td>
#       <td id="T_71c76_row8_col1" class="data row8 col1" >35</td>
#       <td id="T_71c76_row8_col2" class="data row8 col2" >H</td>
#       <td id="T_71c76_row8_col3" class="data row8 col3" >90.000000</td>
#       <td id="T_71c76_row8_col4" class="data row8 col4" >1,94</td>
#       <td id="T_71c76_row8_col5" class="data row8 col5" >241.000000</td>
#     </tr>
#     <tr>
#       <th id="T_71c76_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_71c76_row9_col0" class="data row9 col0" >Santiago Reillo Manzano</td>
#       <td id="T_71c76_row9_col1" class="data row9 col1" >46</td>
#       <td id="T_71c76_row9_col2" class="data row9 col2" >H</td>
#       <td id="T_71c76_row9_col3" class="data row9 col3" >75.000000</td>
#       <td id="T_71c76_row9_col4" class="data row9 col4" >1,85</td>
#       <td id="T_71c76_row9_col5" class="data row9 col5" >280.000000</td>
#     </tr>
#     <tr>
#       <th id="T_71c76_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_71c76_row10_col0" class="data row10 col0" >Macarena Álvarez Luna</td>
#       <td id="T_71c76_row10_col1" class="data row10 col1" >53</td>
#       <td id="T_71c76_row10_col2" class="data row10 col2" >M</td>
#       <td id="T_71c76_row10_col3" class="data row10 col3" >55.000000</td>
#       <td id="T_71c76_row10_col4" class="data row10 col4" >1,62</td>
#       <td id="T_71c76_row10_col5" class="data row10 col5" >262.000000</td>
#     </tr>
#     <tr>
#       <th id="T_71c76_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_71c76_row11_col0" class="data row11 col0" >José María de la Guía Sanz</td>
#       <td id="T_71c76_row11_col1" class="data row11 col1" >58</td>
#       <td id="T_71c76_row11_col2" class="data row11 col2" >H</td>
#       <td id="T_71c76_row11_col3" class="data row11 col3" >78.000000</td>
#       <td id="T_71c76_row11_col4" class="data row11 col4" >1,87</td>
#       <td id="T_71c76_row11_col5" class="data row11 col5" >198.000000</td>
#     </tr>
#     <tr>
#       <th id="T_71c76_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_71c76_row12_col0" class="data row12 col0"

# %%
styled_df = df.style.bar(subset=['colesterol'], color='lightblue')
styled_df
# Out:
# <style type="text/css">
# #T_35b12_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 65.0%, transparent 65.0%);
# }
# #T_35b12_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 82.9%, transparent 82.9%);
# }
# #T_35b12_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 68.2%, transparent 68.2%);
# }
# #T_35b12_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 71.4%, transparent 71.4%);
# }
# #T_35b12_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 52.9%, transparent 52.9%);
# }
# #T_35b12_row5_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 88.9%, transparent 88.9%);
# }
# #T_35b12_row6_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 98.6%, transparent 98.6%);
# }
# #T_35b12_row7_col5 {
#   width: 10em;
# }
# #T_35b12_row8_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 86.1%, transparent 86.1%);
# }
# #T_35b12_row9_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_35b12_row10_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 93.6%, transparent 93.6%);
# }
# #T_35b12_row11_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 70.7%, transparent 70.7%);
# }
# #T_35b12_row12_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 75.0%, transparent 75.0%);
# }
# #T_35b12_row13_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 69.3%, transparent 69.3%);
# }
# </style>
# <table id="T_35b12">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35b12_level0_col0" class="col_heading level0 col0" >nombre</th>
#       <th id="T_35b12_level0_col1" class="col_heading level0 col1" >edad</th>
#       <th id="T_35b12_level0_col2" class="col_heading level0 col2" >sexo</th>
#       <th id="T_35b12_level0_col3" class="col_heading level0 col3" >peso</th>
#       <th id="T_35b12_level0_col4" class="col_heading level0 col4" >altura</th>
#       <th id="T_35b12_level0_col5" class="col_heading level0 col5" >colesterol</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35b12_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_35b12_row0_col0" class="data row0 col0" >José Luis Martínez Izquierdo</td>
#       <td id="T_35b12_row0_col1" class="data row0 col1" >18</td>
#       <td id="T_35b12_row0_col2" class="data row0 col2" >H</td>
#       <td id="T_35b12_row0_col3" class="data row0 col3" >85.000000</td>
#       <td id="T_35b12_row0_col4" class="data row0 col4" >1,79</td>
#       <td id="T_35b12_row0_col5" class="data row0 col5" >182.000000</td>
#     </tr>
#     <tr>
#       <th id="T_35b12_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_35b12_row1_col0" class="data row1 col0" >Rosa Díaz Díaz</td>
#       <td id="T_35b12_row1_col1" class="data row1 col1" >32</td>
#       <td id="T_35b12_row1_col2" class="data row1 col2" >M</td>
#       <td id="T_35b12_row1_col3" class="data row1 col3" >65.000000</td>
#       <td id="T_35b12_row1_col4" class="data row1 col4" >1,73</td>
#       <td id="T_35b12_row1_col5" class="data row1 col5" >232.000000</td>
#     </tr>
#     <tr>
#       <th id="T_35b12_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_35b12_row2_col0" class="data row2 col0" >Javier García Sánchez</td>
#       <td id="T_35b12_row2_col1" class="data row2 col1" >24</td>
#       <td id="T_35b12_row2_col2" class="data row2 col2" >H</td>
#       <td id="T_35b12_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_35b12_row2_col4" class="data row2 col4" >1,81</td>
#       <td id="T_35b12_row2_col5" class="data row2 col5" >191.000000</td>
#     </tr>
#     <tr>
#       <th id="T_35b12_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_35b12_row3_col0" class="data row3 col0" >Carmen López Pinzón</td>
#       <td id="T_35b12_row3_col1" class="data row3 col1" >35</td>
#       <td id="T_35b12_row3_col2" class="data row3 col2" >M</td>
#       <td id="T_35b12_row3_col3" class="data row3 col3" >65.000000</td>
#       <td id="T_35b12_row3_col4" class="data row3 col4" >1,70</td>
#       <td id="T_35b12_row3_col5" class="data row3 col5" >200.000000</td>
#     </tr>
#     <tr>
#       <th id="T_35b12_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_35b12_row4_col0" class="data row4 col0" >Marisa López Collado</td>
#       <td id="T_35b12_row4_col1" class="data row4 col1" >46</td>
#       <td id="T_35b12_row4_col2" class="data row4 col2" >M</td>
#       <td id="T_35b12_row4_col3" class="data row4 col3" >51.000000</td>
#       <td id="T_35b12_row4_col4" class="data row4 col4" >1,58</td>
#       <td id="T_35b12_row4_col5" class="data row4 col5" >148.000000</td>
#     </tr>
#     <tr>
#       <th id="T_35b12_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_35b12_row5_col0" class="data row5 col0" >Antonio Ruiz Cruz</td>
#       <td id="T_35b12_row5_col1" class="data row5 col1" >68</td>
#       <td id="T_35b12_row5_col2" class="data row5 col2" >H</td>
#       <td id="T_35b12_row5_col3" class="data row5 col3" >66.000000</td>
#       <td id="T_35b12_row5_col4" class="data row5 col4" >1,74</td>
#       <td id="T_35b12_row5_col5" class="data row5 col5" >249.000000</td>
#     </tr>
#     <tr>
#       <th id="T_35b12_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_35b12_row6_col0" class="data row6 col0" >Antonio Fernández Ocaña</td>
#       <td id="T_35b12_row6_col1" class="data row6 col1" >51</td>
#       <td id="T_35b12_row6_col2" class="data row6 col2" >H</td>
#       <td id="T_35b12_row6_col3" class="data row6 col3" >62.000000</td>
#       <td id="T_35b12_row6_col4" class="data row6 col4" >1,72</td>
#       <td id="T_35b12_row6_col5" class="data row6 col5" >276.000000</td>
#     </tr>
#     <tr>
#       <th id="T_35b12_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_35b12_row7_col0" class="data row7 col0" >Pilar Martín González</td>
#       <td id="T_35b12_row7_col1" class="data row7 col1" >22</td>
#       <td id="T_35b12_row7_col2" class="data row7 col2" >M</td>
#       <td id="T_35b12_row7_col3" class="data row7 col3" >60.000000</td>
#       <td id="T_35b12_row7_col4" class="data row7 col4" >1,66</td>
#       <td id="T_35b12_row7_col5" class="data row7 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_35b12_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_35b12_row8_col0" class="data row8 col0" >Pedro Gálvez Tenorio</td>
#       <td id="T_35b12_row8_col1" class="data row8 col1" >35</td>
#       <td id="T_35b12_row8_col2" class="data row8 col2" >H</td>
#       <td id="T_35b12_row8_col3" class="data row8 col3" >90.000000</td>
#       <td id="T_35b12_row8_col4" class="data row8 col4" >1,94</td>
#       <td id="T_35b12_row8_col5" class="data row8 col5" >241.000000</td>
#     </tr>
#     <tr>
#       <th id="T_35b12_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_35b12_row9_col0" class="data row9 col0" >Santiago Reillo Manzano</td>
#       <td id="T_35b12_row9_col1" class="data row9 col1" >46</td>
#       <td id="T_35b12_row9_col2" class="data row9 col2" >H</td>
#       <td id="T_35b12_row9_col3" class="data row9 col3" >75.000000</td>
#       <td id="T_35b12_row9_col4" class="data row9 col4" >1,85</td>
#       <td id="T_35b12_row9_col5" class="data row9 col5" >280.000000</td>
#     </tr>
#     <tr>
#       <th id="T_35b12_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_35b12_row10_col0" class="data row10 col0" >Macarena Álvarez Luna</td>
#       <td id="T_35b12_row10_col1" class="data row10 col1" >53</td>
#       <td id="T_35b12_row10_col2" class="data row10 col2" >M</td>
#       <td id="T_35b12_row10_col3" class="data row10 col3" >55.000000</td>
#       <td id="T_35b12_row10_col4" class="data row10 col4" >1,62</td>
#       <td id="T_35b12_row10_col5" class="data row10 col5" >262.000000</td>
#     </tr>
#     <tr>
#       <th id="T_35b12_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_35b12_row11_col0" class="data row11 col0" >José María de la Guía

# %%
def highlight_age(row):
    return ['background-color: yellow' if v > 25 else '' for v in row]

styled_df = df.style.apply(highlight_age, subset=['edad'])
styled_df
# Out:
# <style type="text/css">
# #T_20f46_row1_col1, #T_20f46_row3_col1, #T_20f46_row4_col1, #T_20f46_row5_col1, #T_20f46_row6_col1, #T_20f46_row8_col1, #T_20f46_row9_col1, #T_20f46_row10_col1, #T_20f46_row11_col1, #T_20f46_row12_col1 {
#   background-color: yellow;
# }
# </style>
# <table id="T_20f46">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20f46_level0_col0" class="col_heading level0 col0" >nombre</th>
#       <th id="T_20f46_level0_col1" class="col_heading level0 col1" >edad</th>
#       <th id="T_20f46_level0_col2" class="col_heading level0 col2" >sexo</th>
#       <th id="T_20f46_level0_col3" class="col_heading level0 col3" >peso</th>
#       <th id="T_20f46_level0_col4" class="col_heading level0 col4" >altura</th>
#       <th id="T_20f46_level0_col5" class="col_heading level0 col5" >colesterol</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20f46_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_20f46_row0_col0" class="data row0 col0" >José Luis Martínez Izquierdo</td>
#       <td id="T_20f46_row0_col1" class="data row0 col1" >18</td>
#       <td id="T_20f46_row0_col2" class="data row0 col2" >H</td>
#       <td id="T_20f46_row0_col3" class="data row0 col3" >85.000000</td>
#       <td id="T_20f46_row0_col4" class="data row0 col4" >1,79</td>
#       <td id="T_20f46_row0_col5" class="data row0 col5" >182.000000</td>
#     </tr>
#     <tr>
#       <th id="T_20f46_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_20f46_row1_col0" class="data row1 col0" >Rosa Díaz Díaz</td>
#       <td id="T_20f46_row1_col1" class="data row1 col1" >32</td>
#       <td id="T_20f46_row1_col2" class="data row1 col2" >M</td>
#       <td id="T_20f46_row1_col3" class="data row1 col3" >65.000000</td>
#       <td id="T_20f46_row1_col4" class="data row1 col4" >1,73</td>
#       <td id="T_20f46_row1_col5" class="data row1 col5" >232.000000</td>
#     </tr>
#     <tr>
#       <th id="T_20f46_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_20f46_row2_col0" class="data row2 col0" >Javier García Sánchez</td>
#       <td id="T_20f46_row2_col1" class="data row2 col1" >24</td>
#       <td id="T_20f46_row2_col2" class="data row2 col2" >H</td>
#       <td id="T_20f46_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_20f46_row2_col4" class="data row2 col4" >1,81</td>
#       <td id="T_20f46_row2_col5" class="data row2 col5" >191.000000</td>
#     </tr>
#     <tr>
#       <th id="T_20f46_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_20f46_row3_col0" class="data row3 col0" >Carmen López Pinzón</td>
#       <td id="T_20f46_row3_col1" class="data row3 col1" >35</td>
#       <td id="T_20f46_row3_col2" class="data row3 col2" >M</td>
#       <td id="T_20f46_row3_col3" class="data row3 col3" >65.000000</td>
#       <td id="T_20f46_row3_col4" class="data row3 col4" >1,70</td>
#       <td id="T_20f46_row3_col5" class="data row3 col5" >200.000000</td>
#     </tr>
#     <tr>
#       <th id="T_20f46_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_20f46_row4_col0" class="data row4 col0" >Marisa López Collado</td>
#       <td id="T_20f46_row4_col1" class="data row4 col1" >46</td>
#       <td id="T_20f46_row4_col2" class="data row4 col2" >M</td>
#       <td id="T_20f46_row4_col3" class="data row4 col3" >51.000000</td>
#       <td id="T_20f46_row4_col4" class="data row4 col4" >1,58</td>
#       <td id="T_20f46_row4_col5" class="data row4 col5" >148.000000</td>
#     </tr>
#     <tr>
#       <th id="T_20f46_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_20f46_row5_col0" class="data row5 col0" >Antonio Ruiz Cruz</td>
#       <td id="T_20f46_row5_col1" class="data row5 col1" >68</td>
#       <td id="T_20f46_row5_col2" class="data row5 col2" >H</td>
#       <td id="T_20f46_row5_col3" class="data row5 col3" >66.000000</td>
#       <td id="T_20f46_row5_col4" class="data row5 col4" >1,74</td>
#       <td id="T_20f46_row5_col5" class="data row5 col5" >249.000000</td>
#     </tr>
#     <tr>
#       <th id="T_20f46_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_20f46_row6_col0" class="data row6 col0" >Antonio Fernández Ocaña</td>
#       <td id="T_20f46_row6_col1" class="data row6 col1" >51</td>
#       <td id="T_20f46_row6_col2" class="data row6 col2" >H</td>
#       <td id="T_20f46_row6_col3" class="data row6 col3" >62.000000</td>
#       <td id="T_20f46_row6_col4" class="data row6 col4" >1,72</td>
#       <td id="T_20f46_row6_col5" class="data row6 col5" >276.000000</td>
#     </tr>
#     <tr>
#       <th id="T_20f46_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_20f46_row7_col0" class="data row7 col0" >Pilar Martín González</td>
#       <td id="T_20f46_row7_col1" class="data row7 col1" >22</td>
#       <td id="T_20f46_row7_col2" class="data row7 col2" >M</td>
#       <td id="T_20f46_row7_col3" class="data row7 col3" >60.000000</td>
#       <td id="T_20f46_row7_col4" class="data row7 col4" >1,66</td>
#       <td id="T_20f46_row7_col5" class="data row7 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_20f46_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_20f46_row8_col0" class="data row8 col0" >Pedro Gálvez Tenorio</td>
#       <td id="T_20f46_row8_col1" class="data row8 col1" >35</td>
#       <td id="T_20f46_row8_col2" class="data row8 col2" >H</td>
#       <td id="T_20f46_row8_col3" class="data row8 col3" >90.000000</td>
#       <td id="T_20f46_row8_col4" class="data row8 col4" >1,94</td>
#       <td id="T_20f46_row8_col5" class="data row8 col5" >241.000000</td>
#     </tr>
#     <tr>
#       <th id="T_20f46_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_20f46_row9_col0" class="data row9 col0" >Santiago Reillo Manzano</td>
#       <td id="T_20f46_row9_col1" class="data row9 col1" >46</td>
#       <td id="T_20f46_row9_col2" class="data row9 col2" >H</td>
#       <td id="T_20f46_row9_col3" class="data row9 col3" >75.000000</td>
#       <td id="T_20f46_row9_col4" class="data row9 col4" >1,85</td>
#       <td id="T_20f46_row9_col5" class="data row9 col5" >280.000000</td>
#     </tr>
#     <tr>
#       <th id="T_20f46_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_20f46_row10_col0" class="data row10 col0" >Macarena Álvarez Luna</td>
#       <td id="T_20f46_row10_col1" class="data row10 col1" >53</td>
#       <td id="T_20f46_row10_col2" class="data row10 col2" >M</td>
#       <td id="T_20f46_row10_col3" class="data row10 col3" >55.000000</td>
#       <td id="T_20f46_row10_col4" class="data row10 col4" >1,62</td>
#       <td id="T_20f46_row10_col5" class="data row10 col5" >262.000000</td>
#     </tr>
#     <tr>
#       <th id="T_20f46_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_20f46_row11_col0" class="data row11 col0" >José María de la Guía Sanz</td>
#       <td id="T_20f46_row11_col1" class="data row11 col1" >58</td>
#       <td id="T_20f46_row11_col2" class="data row11 col2" >H</td>
#       <td id="T_20f46_row11_col3" class="data row11 col3" >78.000000</td>
#       <td id="T_20f46_row11_col4" class="data row11 col4" >1,87</td>
#       <td id="T_20f46_row11_col5" class="data row11 col5" >198.000000</td>
#     </tr>
#     <tr>
#       <th id="T_20f46_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_20f46_row12_col0" class="data row12 col0" >Miguel Angel Cuadrado Gutiérrez</td>
#       <td id="T_20f46_row12_col1" class="data row12 col1" >27</td>
#       <td id="T_20f46_row12_col2" class="data row12 col2" >H</td>
#       <td id="T_20f46_row12_col3" class="data row12 col3" >109.000000</td>
#       <td id="T_20f46_row12_col4" class="data row12 col4" >1,98</td>
#       <td id="T_20f46_row12_col5" class="data row12 col5" >210.000000</td>
#     </tr>
#     <tr>
#       <th id="T_20f46_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_20f46_row13_col0" class="data row13 col0" >Carolina Rubio Moreno</td>
#       <td id="T_20f46_row13_col1" class="data row13 col1" >20</td>
#       <td id="T_20f46_row13_col2" class="data row13 col2" >M</td>
#       <td id="T_20f46_row13_col3" class="da

# %%
def highlight_max_min(s):
    is_max = s == s.max()
    is_min = s == s.min()
    return ['background-color: lightgreen' if v else 'background-color: lightcoral' if v else '' for v in is_max | is_min]

styled_df = df.style.apply(highlight_max_min, subset=['colesterol'])
styled_df
# Out:
# <style type="text/css">
# #T_f22c8_row4_col5, #T_f22c8_row9_col5 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f22c8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f22c8_level0_col0" class="col_heading level0 col0" >nombre</th>
#       <th id="T_f22c8_level0_col1" class="col_heading level0 col1" >edad</th>
#       <th id="T_f22c8_level0_col2" class="col_heading level0 col2" >sexo</th>
#       <th id="T_f22c8_level0_col3" class="col_heading level0 col3" >peso</th>
#       <th id="T_f22c8_level0_col4" class="col_heading level0 col4" >altura</th>
#       <th id="T_f22c8_level0_col5" class="col_heading level0 col5" >colesterol</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f22c8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f22c8_row0_col0" class="data row0 col0" >José Luis Martínez Izquierdo</td>
#       <td id="T_f22c8_row0_col1" class="data row0 col1" >18</td>
#       <td id="T_f22c8_row0_col2" class="data row0 col2" >H</td>
#       <td id="T_f22c8_row0_col3" class="data row0 col3" >85.000000</td>
#       <td id="T_f22c8_row0_col4" class="data row0 col4" >1,79</td>
#       <td id="T_f22c8_row0_col5" class="data row0 col5" >182.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f22c8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f22c8_row1_col0" class="data row1 col0" >Rosa Díaz Díaz</td>
#       <td id="T_f22c8_row1_col1" class="data row1 col1" >32</td>
#       <td id="T_f22c8_row1_col2" class="data row1 col2" >M</td>
#       <td id="T_f22c8_row1_col3" class="data row1 col3" >65.000000</td>
#       <td id="T_f22c8_row1_col4" class="data row1 col4" >1,73</td>
#       <td id="T_f22c8_row1_col5" class="data row1 col5" >232.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f22c8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f22c8_row2_col0" class="data row2 col0" >Javier García Sánchez</td>
#       <td id="T_f22c8_row2_col1" class="data row2 col1" >24</td>
#       <td id="T_f22c8_row2_col2" class="data row2 col2" >H</td>
#       <td id="T_f22c8_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_f22c8_row2_col4" class="data row2 col4" >1,81</td>
#       <td id="T_f22c8_row2_col5" class="data row2 col5" >191.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f22c8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f22c8_row3_col0" class="data row3 col0" >Carmen López Pinzón</td>
#       <td id="T_f22c8_row3_col1" class="data row3 col1" >35</td>
#       <td id="T_f22c8_row3_col2" class="data row3 col2" >M</td>
#       <td id="T_f22c8_row3_col3" class="data row3 col3" >65.000000</td>
#       <td id="T_f22c8_row3_col4" class="data row3 col4" >1,70</td>
#       <td id="T_f22c8_row3_col5" class="data row3 col5" >200.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f22c8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f22c8_row4_col0" class="data row4 col0" >Marisa López Collado</td>
#       <td id="T_f22c8_row4_col1" class="data row4 col1" >46</td>
#       <td id="T_f22c8_row4_col2" class="data row4 col2" >M</td>
#       <td id="T_f22c8_row4_col3" class="data row4 col3" >51.000000</td>
#       <td id="T_f22c8_row4_col4" class="data row4 col4" >1,58</td>
#       <td id="T_f22c8_row4_col5" class="data row4 col5" >148.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f22c8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f22c8_row5_col0" class="data row5 col0" >Antonio Ruiz Cruz</td>
#       <td id="T_f22c8_row5_col1" class="data row5 col1" >68</td>
#       <td id="T_f22c8_row5_col2" class="data row5 col2" >H</td>
#       <td id="T_f22c8_row5_col3" class="data row5 col3" >66.000000</td>
#       <td id="T_f22c8_row5_col4" class="data row5 col4" >1,74</td>
#       <td id="T_f22c8_row5_col5" class="data row5 col5" >249.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f22c8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f22c8_row6_col0" class="data row6 col0" >Antonio Fernández Ocaña</td>
#       <td id="T_f22c8_row6_col1" class="data row6 col1" >51</td>
#       <td id="T_f22c8_row6_col2" class="data row6 col2" >H</td>
#       <td id="T_f22c8_row6_col3" class="data row6 col3" >62.000000</td>
#       <td id="T_f22c8_row6_col4" class="data row6 col4" >1,72</td>
#       <td id="T_f22c8_row6_col5" class="data row6 col5" >276.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f22c8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f22c8_row7_col0" class="data row7 col0" >Pilar Martín González</td>
#       <td id="T_f22c8_row7_col1" class="data row7 col1" >22</td>
#       <td id="T_f22c8_row7_col2" class="data row7 col2" >M</td>
#       <td id="T_f22c8_row7_col3" class="data row7 col3" >60.000000</td>
#       <td id="T_f22c8_row7_col4" class="data row7 col4" >1,66</td>
#       <td id="T_f22c8_row7_col5" class="data row7 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f22c8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f22c8_row8_col0" class="data row8 col0" >Pedro Gálvez Tenorio</td>
#       <td id="T_f22c8_row8_col1" class="data row8 col1" >35</td>
#       <td id="T_f22c8_row8_col2" class="data row8 col2" >H</td>
#       <td id="T_f22c8_row8_col3" class="data row8 col3" >90.000000</td>
#       <td id="T_f22c8_row8_col4" class="data row8 col4" >1,94</td>
#       <td id="T_f22c8_row8_col5" class="data row8 col5" >241.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f22c8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f22c8_row9_col0" class="data row9 col0" >Santiago Reillo Manzano</td>
#       <td id="T_f22c8_row9_col1" class="data row9 col1" >46</td>
#       <td id="T_f22c8_row9_col2" class="data row9 col2" >H</td>
#       <td id="T_f22c8_row9_col3" class="data row9 col3" >75.000000</td>
#       <td id="T_f22c8_row9_col4" class="data row9 col4" >1,85</td>
#       <td id="T_f22c8_row9_col5" class="data row9 col5" >280.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f22c8_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f22c8_row10_col0" class="data row10 col0" >Macarena Álvarez Luna</td>
#       <td id="T_f22c8_row10_col1" class="data row10 col1" >53</td>
#       <td id="T_f22c8_row10_col2" class="data row10 col2" >M</td>
#       <td id="T_f22c8_row10_col3" class="data row10 col3" >55.000000</td>
#       <td id="T_f22c8_row10_col4" class="data row10 col4" >1,62</td>
#       <td id="T_f22c8_row10_col5" class="data row10 col5" >262.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f22c8_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f22c8_row11_col0" class="data row11 col0" >José María de la Guía Sanz</td>
#       <td id="T_f22c8_row11_col1" class="data row11 col1" >58</td>
#       <td id="T_f22c8_row11_col2" class="data row11 col2" >H</td>
#       <td id="T_f22c8_row11_col3" class="data row11 col3" >78.000000</td>
#       <td id="T_f22c8_row11_col4" class="data row11 col4" >1,87</td>
#       <td id="T_f22c8_row11_col5" class="data row11 col5" >198.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f22c8_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f22c8_row12_col0" class="data row12 col0" >Miguel Angel Cuadrado Gutiérrez</td>
#       <td id="T_f22c8_row12_col1" class="data row12 col1" >27</td>
#       <td id="T_f22c8_row12_col2" class="data row12 col2" >H</td>
#       <td id="T_f22c8_row12_col3" class="data row12 col3" >109.000000</td>
#       <td id="T_f22c8_row12_col4" class="data row12 col4" >1,98</td>
#       <td id="T_f22c8_row12_col5" class="data row12 col5" >210.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f22c8_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f22c8_row13_col0" class="data row13 col0" >Carolina Rubio Moreno</td>
#       <td id="T_f22c8_row13_col1" class="data row13 col1" >20</td>
#       <td id="T_f22c8_row13_col2" class="data row13 col2" >M</td>
#       <td id="T_f22c8_row13_col3" class="data row13 col3" >61.000000</td>
#       <td id="T_f22c8_row13_col4" class="data row13 col4" >1,77</td>
#       <td id="T_f22c8_row13_col5" class="data row13 col5" >

# %%
styled_df.to_html('styled_dataframe.html')

# %%
df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [24, 27, 22, 32],
    'Score': [85, 90, 88, 95]
})


styled_df = df.style \
    .highlight_max(color='lightgreen', axis=0) \
    .highlight_min(color='lightcoral', axis=0) \
    .format({'Score': '{:.2f}'}) \
    .background_gradient(subset=['Score'], cmap='viridis') \
    .bar(subset=['Score'], color='lightblue')


styled_df

# styled_df.to_html('styled_dataframe.html')

# %% [markdown]
# ## Renombrar los nombres de las filas y columnas

# %% [markdown]
# Para cambiar el nombre de las filas y las columnas de un DataFrame se utiliza el siguiente método:
#
# <center><code>df.rename(columns=columnas, index=filas)</code></center>
#
# Devuelve el DataFrame que resulta de renombrar las columnas indicadas en las claves del diccionario columnas con sus valores y las filas indicadas en las claves del diccionario filas con sus valores en el DataFrame df.

# %%
import pandas as pd
df = pd.read_csv('./Archivos/colesterol.csv', sep = ';',decimal=',')
nuevodf =  df.rename(columns={'nombre':'nombre y apellidos', 'altura':'estatura'}, index={0:1000, 1:1001, 2:1002})
print(nuevodf)

# %% [markdown]
# ## Cambiar el índice de un DataFrame

# %% [markdown]
# Aunque el índice de un DataFrame suele fijarse en la creación del mismo, en ocasiones puede ser necesario cambiar el índice una vez creado el DataFrame. Para ello se utiliza el siguiente método:
#
# <center><code>df.set_index(keys = columnas, verify_integrity = bool, drop=True, inplace=False)</code></center>
#
# * Devuelve el `DataFrame` que resulta de eliminar las columnas de la lista columnas y convertirlas en el nuevo índice.
#
# * El parámetro `verify_integrity` recibe un booleano (`False` por defecto) y realiza una comprobación para evitar duplicados en la clave cuando recibe `True`.
#
# * `drop`: Es un valor booleano que indica si las columnas seleccionadas deben eliminarse del DataFrame. Si se establece en `True`, las columnas se eliminarán; si se establece en `False`, las columnas seleccionadas permanecerán en el DataFrame.
#
# * `inplace`: Es un valor booleano que indica si se debe modificar el DataFrame original. Si se establece en `True`, el DataFrame original se modificará y no se devolverá un nuevo DataFrame; si se establece en `False`, se devolverá un nuevo DataFrame con el índice modificado y el DataFrame original no se verá afectado.

# %%
import pandas as pd
df = pd.read_csv('./Archivos/colesterol.csv', sep = ';',decimal=',')
df

# %%
import pandas as pd
df = pd.read_csv('./Archivos/colesterol.csv', sep = ';',decimal=',')
df.set_index(["nombre","edad"], inplace = True)
df

# %% [markdown]
# ## Reindexar un DataFrame

# %% [markdown]
# Para **reordenar los índices de las filas y las columnas** de un `DataFrame`, así como añadir o eliminar índices, se utiliza el siguiente método:
#
# <center><code>df.reindex(index=filas, columns=columnas, fill_value=relleno)</code></center>

# %% [markdown]
# * Devuelve el `DataFrame` que resulta de tomar del DataFrame `df` las filas con nombres en la lista `filas` y las columnas con nombres en la lista `columnas`.
#
# * `fill_value`: Especifica el valor para rellenar los elementos faltantes en el DataFrame después de la reindexación. Si alguno de los nombres indicados en filas o columnas no existía en el DataFrame `df`, se crean filan o columnas nuevas rellenas con el valor `relleno`.

# %%
import pandas as pd
df = pd.read_csv('./Archivos/colesterol.csv', sep = ';',decimal=',')

print(df.reindex(index=[4, 3, 1], columns=['nombre', 'tensión', 'colesterol']))

# %% [markdown]
# ## Acceso a los elementos de un DataFrame

# %% [markdown]
# El acceso a los datos de un DataFrame se puede hacer a través de posiciones o través de los nombres de las filas y columnas.

# %% [markdown]
# ## Accesos mediante posiciones

# %% [markdown]
# * <center><code>df.iloc[i, j]</code> </center>
#
# Devuelve el elemento que se encuentra en la fila `i` y la columna `j` del DataFrame `df`. Pueden indicarse secuencias de índices para obtener partes del DataFrame.
#
# * <center><code>df.iloc[filas, columnas]</code> </center>
#
# Devuelve un DataFrame con los elementos de las filas de la lista `filas` y de las columnas de la lista `columnas`.
#
# * <center><code>df.iloc[i]</code> </center>
#
# Devuelve una serie con los elementos de la fila `i` del DataFrame `df`.

# %%
import pandas as pd
df = pd.read_csv('./Archivos/colesterol.csv', sep = ';',decimal=',')
print(df)
print(df.iloc[1,3])

print(df.iloc[:,0])

# %% [markdown]
# ## Acceso a los elementos mediante nombres

# %% [markdown]
# * <center><code>df.loc[fila, columna]</code> </center>
#
# Devuelve el elemento que se encuentra en la fila con nombre `fila` y la columna de con nombre `columna` del DataFrame `df`.
#
# * <center><code>df.loc[filas, columnas]</code> </center>
#
# Devuelve un DataFrame con los elementos que se encuentra en las filas con los nombres de la lista `filas` y las columnas con los nombres de la lista `columnas` del DataFrame `df`.
#
# * <center><code>df[columna]</code> </center>
#
# Devuelve una serie con los elementos de la columna de nombre `columna` del DataFrame `df`.
#
# * <center><code>df.columna</code> </center>
#
# Devuelve una serie con los elementos de la columna de nombre columna del DataFrame `df`. Es similar al método anterior pero **sólo funciona cuando el nombre de la columna no tiene espacios en blanco.**

# %%
import pandas as pd
df = pd.read_csv('./Archivos/colesterol.csv', sep = ';',decimal=',')

#print(df.loc[2,'colesterol'])

#print(df.loc[:3,('colesterol','peso')])

#print(df['colesterol'])

print(df.colesterol)

# %% [markdown]
# ## Operaciones con las columnas de un DataFrame

# %% [markdown]
# ### Añadir columnas a un DataFrame

# %% [markdown]
# El procedimiento para añadir una nueva columna a un DataFrame es similar al de añadir un nuevo par aun diccionario, pero pasando los valores de la columna en una lista o serie:
#
# <center><code>df[nombre] = lista </code></center>
#
# Añade al DataFrame `df` una nueva columna con el nombre nombre y los valores de la lista `lista`. La lista debe tener el mismo tamaño que el número de filas de `df`.
#
# <center><code>df[nombre] = serie</code></center>
#
# Añade al DataFrame `df` una nueva columna con el nombre `nombre` y los valores de la serie `serie`. Si el tamaño de la serie es menor que el número de filas de `df` se rellena con valores `NaN` mientras que si es mayor se recorta.

# %%
import pandas as pd
df = pd.read_csv('./Archivos/colesterol.csv', sep = ';',decimal=',')

df['diabetes']=pd.Series([False,False,True,False,True])
print(df)

# %%
print(df['colesterol'].sum()/12)
print(df['colesterol'].sum()/13)

print(df['colesterol'].mean())

# %% [markdown]
# ### Operaciones sobre columnas

# %% [markdown]
# Puesto que los datos de una misma columna de un DataFrame son del mismo tipo, es fácil aplicar la misma operación a todos los elementos de la columna como si de una serie se tratará.

# %%
import pandas as pd
df = pd.read_csv('./Archivos/colesterol.csv', sep = ';',decimal=',')
print(df['altura']*100)

# %%
print(df['sexo']=='M')

# %% [markdown]
# ### Aplicar funciones a columnas

# %% [markdown]
# Para aplicar funciones a todos los elementos de una columna se utiliza el siguiente método
# <center><code>df[columna].apply(f)</code></center>
#
# Devuelve una serie con los valores que resulta de aplicar la función `f` a los elementos de la columna con nombre columna del DataFrame `df`.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('./Archivos/colesterol.csv', sep = ';',decimal=',')

def f(x):
    return 2*np.exp(x)


print(df['altura'].apply(lambda x : 2*np.exp(x)))
print(df['altura'].apply(f))

# %% [markdown]
# ### Convertir una columna al tipo datetime

# %% [markdown]
# A menudo una columna contiene cadenas que representan fechas. Para convertir estas cadenas al tipo datetime se utiliza el siguiente método:

# %% [markdown]
# <center><code>to_datetime(columna, formato)</code></center>
#
# Devuelve la serie que resulta de convertir las cadenas de la `columna` con el nombre columna en fechas del tipo `datetime` con el formado especificado en formato.

# %%
import pandas as pd

df=pd.DataFrame({'Nombre':['María','Carlos','Carmen'],'Nacimiento':['05-03-2000', '20-05-2001', '10-12-1999']})
print(pd.to_datetime(df.Nacimiento,format='%d-%m-%Y'))

# %% [markdown]
# ### Resumen descriptivo de un DataFrame

# %% [markdown]
# Al igual que para las series, los siguientes métodos permiten resumir la información de un DataFrame por columnas:

# %% [markdown]
# * `df.count()`: Devuelve una serie con el número de elementos que no son nulos ni `NaN` en cada columna del DataFrame `df`.
#
# * `df.sum()`: Devuelve una serie con la suma de los datos de las columnas del DataFrame `df` cuando los datos son de un tipo numérico, o la concatenación de ellos cuando son del tipo cadena `str`.
#
# * `df.cumsum()`: Devuelve un DataFrame con la suma acumulada de los datos de las columnas del DataFrame `df` cuando los datos son de un tipo numérico.
#
# * `df.min()`: Devuelve una serie con los menores de los datos de las columnas del DataFrame `df`.
#
# * `df.max()`: Devuelve una serie con los mayores de los datos de las columnas del DataFrame `df`.
#
# * `df.mean()`: Devuelve una serie con las medias de los datos de las columnas numéricas del DataFrame `df`.
#
# * `df.var()`: Devuelve una serie con las varianzas de los datos de las columnas numéricas del DataFrame `df`.
#
# * `df.std()`: Devuelve una serie con las desviaciones típicas de los datos de las columnas numéricas del DataFrame `df`.
#
# * `df.cov()`: Devuelve un DataFrame con las covarianzas de los datos de las columnas numéricas del DataFrame `df`.
#
# * `df.corr()`: Devuelve un DataFrame con los coeficientes de correlación de Pearson de los datos de las columnas numéricas del DataFrame `df`.
#
# * `df.describe(include = tipo)`: Devuelve un DataFrame con un resumen estadístico de las columnas del DataFrame `df` del tipo tipo. Para los datos numéricos (`number`) se calcula la media, la desviación típica, el mínimo, el máximo y los cuartiles. Para los datos no numéricos (`object`) se calcula el número de valores, el número de valores distintos, la moda y su frecuencia. Si no se indica el tipo solo se consideran las columnas numéricas

# %%
import pandas as pd
df = pd.read_csv('./Archivos/colesterol.csv', sep = ';',decimal=',')
df

# %%
df.diabetes.isnull().sum()

# %%
print(df.edad.mean())

# %%
print(df.edad.var())

# %%
print(df.edad.std())

# %%
df.cov()

# %%
df.corr()

# %%
print(df.describe())

# %%
print(df.describe(include='object'))

# %% [markdown]
# **Observaión:** Al utilizar el parámetro include='object' en el método describe(), se generará un resumen estadístico de las columnas de tipo objeto (cadenas de texto) en el data frame. Esto te proporcionará información descriptiva sobre estas columnas.
#
# El resultado será un nuevo data frame que contiene la siguiente información para cada columna de tipo objeto:
#
# * `count`: el número de valores no nulos en la columna.
#
# * `unique`: el número de valores únicos en la columna.
#
# * `top`: el valor más frecuente en la columna.
#
# * `freq`: la frecuencia del valor más frecuente en la columna.

# %% [markdown]
# ### Eliminar columnas de un DataFrame

# %% [markdown]
# Para eliminar columnas de un DataFrame se utilizan los siguientes métodos:
#
# <center> <code> del d[nombre]</code></center>
#
# Elimina la columna con nombre nombre del DataFrame df.
#
# <center> <code> df.pop(nombre) </code></center>
#
# Elimina la columna con nombre nombre del DataFrame df y la devuelve como una serie.

# %%
import pandas as pd
df = pd.read_csv('./Archivos/colesterol.csv', sep = ';',decimal=',')
edad = df.pop('edad')
df

# %% [markdown]
# ## Operaciones con las filas de un DataFrame

# %% [markdown]
# ### Añadir una fila a un DataFrame

# %% [markdown]
# Para añadir una fila a un DataFrame se utiliza el siguiente método:
#
# <center><code>df.append(serie, ignore_index=True)</code></center>
#
# Devuelve el DataFrame que resulta de añadir una fila al DataFrame `df` con los valores de la serie `serie`. Los nombres del índice de la serie deben corresponderse con los nombres de las columnas de `df`. Si no se pasa el parámetro `ignore_index` entonces debe pasarse el parámetro `name` a la serie, donde su argumento será el nombre de la nueva fila.

# %%
df = df.append(pd.Series(['Carlos Rivas', 28, 'H', 89.0, 1.78, 245.0], index=['nombre','edad','sexo','peso','altura','colesterol']), ignore_index=True)
print(df.tail())

# %% [markdown]
# ### Eliminar filas de un DataFrame

# %% [markdown]
# Para eliminar filas de un DataFrame se utilizan el siguiente método:
#
# <center><code> df.drop(filas) </code></center>
#
# Devuelve el DataFrame que resulta de eliminar las `filas` con los nombres indicados en la lista filas del DataFrame `df`.

# %%
print(df.drop([1, 3]))

# %% [markdown]
# ### Filtrar las filas de un DataFrame

# %% [markdown]
# Una operación bastante común con un DataFrame es obtener las filas que cumplen una determinada condición.
#
# <center><code>df[condicion]</code></center>
#
# Devuelve un DataFrame con las filas del DataFrame `df` que se corresponden con el valor `True` de la lista booleana `condicion`. condicion debe ser una lista de valores booleanos de la misma longitud que el número de filas del DataFrame.

# %%
import pandas as pd
df = pd.read_csv('./Archivos/colesterol.csv', sep = ';',decimal=',')
print(df[(df['sexo']=='H') & (df['colesterol'] > 260)])

# %% [markdown]
# ### Ordenar un DataFrame

# %% [markdown]
# Para ordenar un DataFrame de acuerdo a los valores de una determinada columna se utilizan los siguientes métodos:
#
# <center><code>df.sort_values(columna, ascending=booleano)</code></center>
#
# Devuelve el DataFrame que resulta de ordenar las filas del DataFrame `df` según los valores del la columna con nombre columna. Si argumento del parámetro `ascending` es `True` el orden es creciente y si es False decreciente.
#
# <center><code>df.sort_index(ascending=booleano)</code></center>
#
# Devuelve el DataFrame que resulta de ordenar las filas del DataFrame `df` según los nombres de las filas. Si el argumento del parámetro `ascending` es `True` el orden es creciente y si es False decreciente.

# %%
import pandas as pd
df = pd.read_csv('./Archivos/colesterol.csv', sep = ';',decimal=',')
print(df.sort_values('colesterol'))

# %% [markdown]
# ## Eliminar las filas con dados desconocidos en un DataFrame

# %% [markdown]
# Para eliminar las filas de un DataFrame que contienen datos desconocidos `NaN` o nulos `None` se utiliza el siguiente método:
#
# <center><code>s.dropna(subset=columnas)</code></center>
#
# Devuelve el DataFrame que resulta de eliminar las filas que contienen algún dato desconocido o nulo en las columnas de la lista `columna` del DataFrame `df`. Si no se pasa un argumento al parámetro subset se aplica a todas las columnas del DataFrame.

# %%
print(df.dropna())
